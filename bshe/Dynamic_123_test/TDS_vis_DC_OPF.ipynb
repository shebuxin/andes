# %%
import andes
import os
import matplotlib.pyplot as plt
# import matplotlib 
# %matplotlib inline
import numpy as np

# %% [markdown]
# # Load case

# %%
andes.config_logger(stream_level=20)

# case path
dir_path = os.path.abspath('..')
loc_path_case1 = '/Dynamic_123_test/case123_REGCV1_v6_trip0sec.xlsx'

case = dir_path + loc_path_case1

# load a case
ssa = andes.load(case,
                 setup=True,
                 no_output=True)
# Out:
# Working directory: "/Users/buxinshe/Documents/git-repo/andes/bshe/Dynamic_123_test"
# > Loaded config from file "/Users/buxinshe/.andes/andes.rc"
# > Loaded generated Python code in "/Users/buxinshe/.andes/pycode".
# Parsing input file "/Users/buxinshe/Documents/git-repo/andes/bshe/Dynamic_123_test/case123_REGCV1_v6_trip0sec.xlsx"...
# Input file parsed in 0.5302 seconds.
# System internal structure set up in 0.0231 seconds.

# %% [markdown]
# # Modify case

# %%
# upper MD
M1 = np.array([1, 1, 1, 1, 1, 1, 1, 1])*8
D1 = np.array([1, 1, 1, 1, 1, 1, 1, 1])*4

# small MD with small signal issue after gen trip
M2 = np.array([1, 1, 1, 1, 1, 1, 1, 1])
D2 = np.array([1, 1, 1, 1, 1, 1, 1, 1])

# smll MD with transient stability issue after gen trip
M3 = np.array([0.0550819 , 0.05      , 0.05      , 0.18360076, 0.07189779,       0.05      , 0.23838847, 0.2688555 ])
D3 = np.array([0.08507053, 0.16234449, 0.12785225, 0.14253555, 0.29025298,       0.05      , 0.05      , 0.075514  ])

# %%
# reset REGCV1 control parameters
ssa.REGCV1.set(
                src='M', 
                idx= ssa.REGCV1.idx.v,
                attr='v',
                value= M1
            )

ssa.REGCV1.set(
                src='D', 
                idx= ssa.REGCV1.idx.v, 
                attr='v',
                value= D1
            )
# Out:
# True

# %%
# reset power setting point
ssa.PV.set(
                src='p0', 
                idx= ssa.PV.idx.v, 
                attr='v',
                value= np.array([0.05 , 0.09 , 0.02 , 0.024, 0.014, 0.012, 0.018, 0.015, 0.016, 0.017])
            )
# Out:
# True

# %%
# reset load
ssa.PQ.set(
                src='p0', 
                idx= ssa.PQ.idx.v, 
                attr='v',
                value= ssa.PQ.p0.v
            )
# Out:
# True

# %%
ssa.PFlow.run()

ssa.TDS.init()
# Out:
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: Off
#    Sparse solver: KLU
#  Solution method: NR method
# Power flow initialized in 0.0035 seconds.
# 0: |F(x)| = 0.65
# 1: |F(x)| = 0.0003177456474
# 2: |F(x)| = 1.320464353e-07
# Converged in 3 iterations in 0.0033 seconds.
# Initialization for dynamics completed in 0.0317 seconds.
# Initialization was successful.
# array([ 1.03271210e-01,  2.05693263e-01,  2.01947598e-01,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.03601892e+00,  9.99296852e-01,
#         9.88207085e-01,  7.77963825e-02,  1.78119870e-01,  1.66913408e-01,
#         9.97169058e-01,  9.78767090e-01,  9.81290597e-01,  9.96250576e-02,
#         2.14009694e-01,  2.00545214e-01,  5.01641211e-02,  9.01723038e-02,
#         7.91913585e-02,  5.01641211e-02,  9.01723038e-02,  7.91913585e-02,
#         1.19582401e+00,  1.08704503e+00,  1.01776949e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  2.52284866e-02, -4.68155240e-03,
#        -2.01538513e-03,  2.54807714e-01, -4.72836793e-02, -2.03553898e-02,
#         1.19582401e+00,  1.08704503e+00,  1.01776949e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  5.01641211e-02,  9.01723038e-02,
#         7.91913585e-02,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         5.01641211e-02,  9.01723038e-02,  7.91913585e-02,  5.01641211e-02,
#         9.01723038e-02,  7.91913585e-02,  5.01641211e-02,  9.01723038e-02,
#         7.91913585e-02, -1.00328242e-01, -1.80344608e-01, -1.58382717e-01,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -5.77959963e-03,
#        -1.24199450e-02, -1.82054747e-02, -9.30751456e-03, -1.00299159e-02,
#        -1.80441719e-02, -1.44307621e-02, -1.48876613e-02,  2.00000000e-02,
#         2.40000000e-02,  1.40000000e-02,  1.20000000e-02,  1.80000000e-02,
#         1.50000000e-02,  1.60000000e-02,  1.70000000e-02, -5.66083322e-03,
#        -3.92022535e-02, -4.70854117e-02, -3.73061705e-02, -9.00626601e-03,
#        -3.49666321e-02, -1.72221626e-02, -1.72574169e-02,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00056608e+00,
#         1.00392023e+00,  1.00470854e+00,  1.00373062e+00,  1.00090063e+00,
#         1.00349666e+00,  1.00172222e+00,  1.00172574e+00,  2.00000000e-03,
#         2.40000000e-03,  1.40000000e-03,  1.20000000e-03,  1.80000000e-03,
#         1.50000000e-03,  1.60000000e-03,  1.70000000e-03,  4.58226037e-15,
#        -2.19869779e-03, -2.22491039e-03, -2.38601918e-03, -2.44600554e-03,
#        -2.53227296e-03, -2.60732361e-03, -3.60038586e-03, -4.51466449e-03,
#        -2.34897094e-03,  1.86539433e-03,  1.79052584e-03, -4.54841293e-03,
#        -6.89278056e-03, -6.64035272e-03, -6.47216964e-03, -6.58457226e-03,
#        -5.77959963e-03, -1.16680964e-02, -1.18184308e-02, -1.19162193e-02,
#        -1.20053412e-02, -1.21630446e-02, -1.22340233e-02, -1.23990857e-02,
#        -1.24280695e-02, -1.24199450e-02, -1.24842069e-02, -1.25528675e-02,
#        -1.26777062e-02, -1.27505476e-02, -1.24872217e-02, -1.25320876e-02,
#        -1.26337702e-02,  4.45290502e-03, -1.32636045e-02, -1.35695452e-02,
#        -1.36599398e-02, -1.36448707e-02, -1.36938501e-02, -1.41716955e-02,
#        -1.42206481e-02, -1.50541938e-02, -1.52049483e-02, -1.56977222e-02,
#        -1.67213735e-02, -1.82054747e-02, -1.62937407e-02, -1.64360552e-02,
#        -1.65347814e-02, -1.66134811e-02, -1.66397179e-02, -8.10003326e-03,
#        -8.66192776e-03, -8.98703057e-03, -9.16168177e-03, -9.30751456e-03,
#        -9.67526383e-03, -9.75034862e-03, -9.78790342e-03, -1.09964190e-02,
#        -1.09951029e-02, -1.01005379e-02, -9.47743682e-03, -9.72023826e-03,
#        -1.00117430e-02, -1.00299159e-02, -1.32359475e-02, -1.34171653e-02,
#        -1.36250479e-02, -1.37726095e-02, -1.38559058e-02, -1.44995331e-02,
#        -1.55474788e-02, -1.67715116e-02, -1.80441719e-02, -1.52645061e-02,
#        -1.58120623e-02, -1.59174565e-02, -1.59648840e-02, -1.63182395e-02,
#        -1.66191276e-02, -1.66983219e-02, -1.67247237e-02, -1.69274356e-02,
#        -1.70722664e-02, -1.62231756e-02, -1.67932005e-02, -1.68464729e-02,
#        -1.70256817e-02, -1.70942195e-02, -1.71684104e-02, -1.72598343e-02,
#        -1.72635903e-02, -1.73474146e-02, -1.73270531e-02, -1.73575350e-02,
#        -1.35329233e-02, -1.37057806e-02, -1.39363785e-02, -1.39992929e-02,
#        -1.36727106e-02, -1.38753212e-02, -1.41186065e-02, -1.44307621e-02,
#        -1.38265307e-02, -1.39622855e-02, -1.41359075e-02, -1.38721922e-02,
#        -1.43480201e-02, -1.45745067e-02, -1.46608820e-02, -1.46499927e-02,
#        -1.48876613e-02, -1.49362474e-02, -1.66397179e-02, -1.38721922e-02,
#         1.00000000e+00,  9.98996685e-01,  9.98919880e-01,  9.98447549e-01,
#         9.98271880e-01,  9.98019171e-01,  9.97799480e-01,  9.98573049e-01,
#         9.98318858e-01,  9.98501260e-01,  9.99232300e-01,  9.99012876e-01,
#         9.98220040e-01,  9.98236742e-01,  9.98600606e-01,  9.98843217e-01,
#         9.98513915e-01,  1.00000000e+00,  9.97355514e-01,  9.96915667e-01,
#         9.96629733e-01,  9.97833111e-01,  9.97371556e-01,  9.98299176e-01,
#         9.97815857e-01,  9.98886656e-01,  1.00000000e+00,  9.99921773e-01,
#         9.98723666e-01,  9.98560672e-01,  9.98465593e-01,  9.99802660e-01,
#         9.99671093e-01,  9.99483126e-01,  1.00000000e+00,  9.96568587e-01,
#         9.96197442e-01,  9.95933319e-01,  9.95977332e-01,  9.95834252e-01,
#         9.96249479e-01,  9.96106438e-01,  9.95965208e-01,  9.95524817e-01,
#         9.95820037e-01,  9.97438524e-01,  1.00000000e+00,  9.94782360e-01,
#         9.94521003e-01,  9.94398233e-01,  9.94295933e-01,  9.94261833e-01,
#         9.98304521e-01,  9.98393270e-01,  9.98482848e-01,  9.99222750e-01,
#         1.00000000e+00,  9.97792377e-01,  9.97572623e-01,  9.97462741e-01,
#         9.96518118e-01,  9.96449153e-01,  9.98509327e-01,  1.00000000e+00,
#         9.99590769e-01,  9.99526577e-01,  1.00000000e+00,  9.95151333e-01,
#         9.94621905e-01,  9.94015199e-01,  9.93584901e-01,  9.93342157e-01,
#         9.94174112e-01,  9.95464302e-01,  9.97416089e-01,  1.00000000e+00,
#         9.93047397e-01,  9.92335626e-01,  9.92198725e-01,  9.92137213e-01,
#         9.91678411e-01,  9.91288137e-01,  9.91185516e-01,  9.91151309e-01,
#         9.90391415e-01,  9.89970697e-01,  9.91800417e-01,  9.91060773e-01,
#         9.90905920e-01,  9.90759431e-01,  9.90560264e-01,  9.90574522e-01,
#         9.90308898e-01,  9.90451256e-01,  9.90207743e-01,  9.90369089e-01,
#         9.90280546e-01,  9.95270750e-01,  9.95045774e-01,  9.94745798e-01,
#         9.94663991e-01,  9.95594759e-01,  9.96195665e-01,  9.97206726e-01,
#         1.00000000e+00,  9.95665590e-01,  9.95269024e-01,  9.94762184e-01,
#         9.95926528e-01,  9.96801155e-01,  9.97648230e-01,  9.97395482e-01,
#         9.98056137e-01,  1.00000000e+00,  9.99857496e-01,  9.94261833e-01,
#         9.95926528e-01,  7.55384450e-02,  2.26977837e-02,  5.66083322e-03,
#         3.92022535e-02,  4.70854117e-02,  3.73061705e-02,  9.00626601e-03,
#         3.49666321e-02,  1.72221626e-02,  1.72574169e-02, -1.95411046e-03,
#         7.90662527e-02,  8.01028042e-02,  4.13906494e-02,  1.39445308e-02,
#         4.23036338e-02,  8.30782975e-02,  7.78514029e-02,  9.86575560e-02,
#         2.13514195e-01,  2.00577729e-01,  9.95121443e-01,  9.76939962e-01,
#         9.79677791e-01,  5.01641211e-02,  9.01723038e-02,  7.91913585e-02,
#         5.01641211e-02,  9.01723038e-02,  7.91913585e-02,  1.19582401e+00,
#         1.08704503e+00,  1.01776949e+00,  1.19582401e+00,  1.08704503e+00,
#         1.01776949e+00,  5.00000000e-02,  9.00000000e-02,  7.90662527e-02,
#         7.55384450e-02,  2.26977837e-02, -1.95411046e-03,  9.95967516e-01,
#         9.78601528e-01,  9.81234819e-01, -1.00259612e-01, -2.14342008e-01,
#        -2.00856619e-01,  9.91741008e-02,  2.13674889e-01,  2.00231473e-01,
#         9.98022954e-01,  9.78933895e-01,  9.81346794e-01,  1.00293834e+00,
#         1.00198230e+00,  1.00156586e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  5.01641211e-02,
#         9.01723038e-02,  7.91913585e-02,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  5.01641211e-02,  9.01723038e-02,  7.91913585e-02,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  5.01641211e-02,
#         9.01723038e-02,  7.91913585e-02,  5.01641211e-02,  9.01723038e-02,
#         7.91913585e-02,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.19582401e+00,  1.08704503e+00,  1.01776949e+00,  1.02522849e+00,
#         9.95318448e-01,  9.97984615e-01,  2.63081283e-01,  6.50255693e-03,
#         0.00000000e+00,  2.52284866e-02, -4.68155240e-03, -2.01538513e-03,
#         2.52284866e-02, -4.68155240e-03, -2.01538513e-03,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  5.01641211e-02,  9.01723038e-02,  7.91913585e-02,
#         5.01641211e-02,  9.01723038e-02,  7.91913585e-02,  5.01641211e-02,
#         9.01723038e-02,  7.91913585e-02,  5.01641211e-02,  9.01723038e-02,
#         7.91913585e-02, -1.00328242e-01, -1.80344608e-01, -1.58382717e-01,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  2.00000000e-02,  2.40000000e-02,  1.40000000e-02,
#         1.20000000e-02,  1.80000000e-02,  1.50000000e-02,  1.60000000e-02,
#         1.70000000e-02,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  2.00000000e-02,  2.40000000e-02,  1.40000000e-02,
#         1.20000000e-02,  1.80000000e-02,  1.50000000e-02,  1.60000000e-02,
#         1.70000000e-02,  5.66083322e-03,  3.92022535e-02,  4.70854117e-02,
#         3.73061705e-02,  9.00626601e-03,  3.49666321e-02,  1.72221626e-02,
#         1.72574169e-02,  2.00000000e-02,  2.40000000e-02,  1.40000000e-02,
#         1.20000000e-02,  1.80000000e-02,  1.50000000e-02,  1.60000000e-02,
#         1.70000000e-02, -5.66083322e-03, -3.92022535e-02, -4.70854117e-02,
#        -3.73061705e-02, -9.00626601e-03, -3.49666321e-02, -1.72221626e-02,
#        -1.72574169e-02,  2.00000000e-02,  2.40000000e-02,  1.40000000e-02,
#         1.20000000e-02,  1.80000000e-02,  1.50000000e-02,  1.60000000e-02,
#         1.70000000e-02, -5.66083322e-03, -3.92022535e-02, -4.70854117e-02,
#        -3.73061705e-02, -9.00626601e-03, -3.49666321e-02, -1.72221626e-02,
#        -1.72574169e-02,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  1.00056608e+00,  1.00392023e+00,  1.00470854e+00,
#         1.00373062e+00,  1.00090063e+00,  1.00349666e+00,  1.00172222e+00,
#         1.00172574e+00,  2.00000000e-03,  2.40000000e-03,  1.40000000e-03,
#         1.20000000e-03,  1.80000000e-03,  1.50000000e-03,  1.60000000e-03,
#         1.70000000e-03])

# %%
ssa.EIG.run()
# Out:
# -> Eigenvalue Analysis:
# 15 states are associated with zero time constants.
#   Positive       0
#   Zeros          7
#   Negative     164
# Eigenvalue analysis finished in 0.0283 seconds.
# True

# %%
# ssa.EIG.plot()

# %%
# get the maximum eigen value
eig     = ssa.EIG.calc_eig()
eig_max = np.max(eig[0].real)
eig_max

# Note:
# For stable scenario, the maximum eigen value is extracted as positive value, but quite close to zero.
# i.e.,  2.608118165881024e-10
# This is the numerical error, and can be ignored.
# This value is supposed to be zero.
# Out:
# 4.089203108396088e-10

# %%
# Turn off stability check in TDS
ssa.TDS.config.criteria = 0

# Turn off simulation progress bar
ssa.TDS.config.no_tqdm = 1

# Simulation time
ssa.TDS.config.tf = 30

ssa.TDS.run()
# Out:
# -> Time Domain Simulation Summary:
# Sparse Solver: KLU
# Simulation time: 0.0-30 s.
# Fixed step size: h=33.33 ms. Shrink if not converged.
# Simulation to t=30.00 sec completed in 0.5370 seconds.
# True

# %%
# Turn off stability check in TDS
ssa.TDS.config.criteria = 0

# Turn off simulation progress bar
ssa.TDS.config.no_tqdm = 1

# Simulation time
ssa.TDS.config.tf = 5

ssa.TDS.run()
# Out:
# Simulation to t=5.00 sec completed in 0.0000 seconds.
# False

# %%
ssa.EIG.run()

eig_     = ssa.EIG.calc_eig()
eig_max_ = np.max(eig[0].real)
eig_max_
# Out:
# -> Eigenvalue Analysis:
# 15 states are associated with zero time constants.
#   Positive       2
#   Zeros          7
#   Negative     162
# Eigenvalue analysis finished in 0.0206 seconds.
# 4.089203108396088e-10

# %%
ssa.TDS.config.tf = 20

# reset load
ssa.PQ.set(
                src='p0', 
                idx= ssa.PQ.idx.v, 
                attr='v',
                value= ssa.PQ.p0.v
            )

ssa.TDS.run()
# Out:
# Simulation to t=20.00 sec completed in 0.0000 seconds.
# False

# %% [markdown]
# # Plot

# %%
ssa.TDS.plt.plot(
                ssa.Bus.v,
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
ssa.TDS.plt.plot(
                [ssa.REGCV1.omega, ssa.GENROU.omega],
                ytimes = 60,
                legend = True
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
ssa.TDS.plt.plot(
                [ssa.REGCV1.Pe, ssa.GENROU.Pe],
                # left = 0.5,
                # right = 5,
                legend = True
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
ssa.TDS.plt.plot(
                ssa.GENROU.Pe,
                # left = 0.5,
                # right = 5,
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
# Power angle
ssa.TDS.plt.plot(
                [ssa.REGCV1.delta, ssa.GENROU.a],   # GENROW angel is bus angle
                legend = True
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %% [markdown]
# ## Extract data
#
# Code clariffication for extracting simulation data after TDS:
#
# ssa.dae.ts.y:  extract **algebra** variable
#
# ssa.dae.ts.x:  extract **state** variable
#
# ....a, .a means the idx of the target variable
#
# CHECK https://docs.andes.app/en/latest/groupdoc/SynGen.html#genrou for model reference

# %%
# Extract time
t = ssa.dae.ts.t
t = t[:, np.newaxis]

# Extract RoCoF
rocof     = ssa.dae.ts.y[:,  ssa.BusROCOF.Wf_y.a]
rocof_sg  = rocof[:, [0,1,2]]
rocof_ibr = rocof[:, [3,4,5,6,7,8,9,10]]
rocof_max = np.max(np.abs(rocof*60))

# Extract frequency
f         = ssa.dae.ts.x[:,  ssa.GENROU.omega.a]
fnadir    = np.min(f)*60 - 60

# Extract voltage
busV      = ssa.dae.ts.y[:,  ssa.Bus.v.a]
busV_min  = np.min(busV)

# Extract power angle
theta           = ssa.dae.ts.y[:, ssa.GENROU.a.a]
delta_theta     = np.max(theta, axis=1) - np.min(theta, axis=1)
delta_theta_max = np.max(delta_theta)

# %% [markdown]
# ## plot RoCoF

# %%
fig = plt.figure(figsize=(8, 3))
plt.subplots_adjust(left=None, bottom=None, right=None,
                    top=None, wspace=0.6, hspace=0.3)
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ibr_legend = ['IBR1','IBR2','IBR3','IBR4','IBR5','IBR6','IBR7','IBR8']
sg_legend = ['SG1', 'SG2', 'SG3']

ax1.plot(
            t,
            rocof_sg * 60,
        )
ax1.set_title('(a)')
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('RoCoF [Hz/s]')
ax1.legend(sg_legend)
# ax1.set_ylim([0.95, 1.12])
# ax1.set_xlim([0, 3600])

ax2.plot(
            t,
            rocof_ibr * 60,
        )
ax2.set_title('(b)')
ax2.set_xlabel('Time [s]')
ax2.set_ylabel('RoCoF [Hz/s]')
ax2.legend(ibr_legend)

# %% [markdown]
# ## Extract data after a specific time

# %%
# idx_t6 = np.min(np.where(t>6)[0])                      # find the idx of time t > 6
# f_t6   = ssa.dae.ts.x[idx_t6:,  ssa.GENROU.omega.a]    # extract the frequency after t = 6

# plt.plot(t[idx_t6:], f_t6)                             # plot the frequency after t = 6

# %% [markdown]
# # Quick results review

# %%
print('Maximum RoCoF: ', rocof_max, 'Hz/s')
print('Frequency nadir: ', fnadir, 'Hz')
print('Maximum angle difference: ', delta_theta_max, 'rad')
print('Minimum voltage: ', busV_min, 'pu')
print('Maximum eigenvalue: ', np.max([eig_max, eig_max_]))
# Out:
# Maximum RoCoF:  0.0 Hz/s
# Frequency nadir:  0.0 Hz
# Maximum angle difference:  0.01393034184184884 rad
# Minimum voltage:  0.9899706967625693 pu
# Maximum eigenvalue:  4.089203108396088e-10
