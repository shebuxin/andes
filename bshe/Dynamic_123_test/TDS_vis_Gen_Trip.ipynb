# %%
import andes
import os
import matplotlib.pyplot as plt
# import matplotlib 
# %matplotlib inline
import numpy as np

# %% [markdown]
# # Load case

# %%
andes.config_logger(stream_level=20)

# case path
dir_path = os.path.abspath('..')
loc_path_case1 = '/Dynamic_123_test/case123_REGCV1_v7.xlsx'

case = dir_path + loc_path_case1

# load a case
ssa = andes.load(case,
                 setup=True,
                 no_output=True)

# use constant power model for PQ
ssa.PQ.config.p2p = 1
ssa.PQ.config.q2q = 1
ssa.PQ.config.p2z = 0
ssa.PQ.config.q2z = 0 # turn off under-voltage PQ-to-Z conversion
ssa.PQ.pq2z = 0
# Out:
# Working directory: "/Users/buxinshe/Documents/git-repo/andes/bshe/Dynamic_123_test"
# > Loaded config from file "/Users/buxinshe/.andes/andes.rc"
# > Reloaded generated Python code of module "pycode".
# Parsing input file "/Users/buxinshe/Documents/git-repo/andes/bshe/Dynamic_123_test/case123_REGCV1_v7.xlsx"...
# Input file parsed in 0.0586 seconds.
# System internal structure set up in 0.0206 seconds.

# %% [markdown]
# # Modify case

# %%
# upper MD
M1 = np.array([1, 1, 1, 1, 1, 1, 1, 1])*6
D1 = np.array([1, 1, 1, 1, 1, 1, 1, 1])*4

# small MD with small signal issue after gen trip
M2 = np.array([1, 1, 1, 1, 1, 1, 1, 1])
D2 = np.array([1, 1, 1, 1, 1, 1, 1, 1])

# smll MD with transient stability issue after gen trip
M3 = np.array([0.0550819 , 0.05      , 0.05      , 0.18360076, 0.07189779,       0.05      , 0.23838847, 0.2688555 ])
D3 = np.array([0.08507053, 0.16234449, 0.12785225, 0.14253555, 0.29025298,       0.05      , 0.05      , 0.075514  ])

#  base
M_base_IV = np.array([1.11814667, 1.21732237, 1.28718068, 1.24605445, 1.27454199, 1.11813483, 1.21832465, 1.25060247]) + 0.4
D_base_IV = np.array([1.07208462, 1.05709857, 0.91479399, 0.90698404, 1.07926447, 0.91375611, 0.9136579 , 1.01812373]) + 0.4

# %%
M_base_IV[0] -= 0.2
M_base_IV[1] -= 0.3
M_base_IV[2] += 0.25
M_base_IV[3] += 0.25
M_base_IV[4] -= 0.2
M_base_IV[5] += 0.25
M_base_IV[6] += 0.25
M_base_IV[7] += 0.25

M_base_IV
# Out:
# array([1.31814667, 1.31732237, 1.93718068, 1.89605445, 1.47454199,
#        1.76813483, 1.86832465, 1.90060247])

# %%
D_base_IV[0] -= 0.9
D_base_IV[1] -= 1.3
D_base_IV[2] += 0.25
D_base_IV[3] += 0.25
D_base_IV[4] -= 0.8
D_base_IV[5] += 0.25
D_base_IV[6] += 0.25
D_base_IV[7] += 0.25

D_base_IV
# Out:
# array([0.57208462, 0.15709857, 1.56479399, 1.55698404, 0.67926447,
#        1.56375611, 1.5636579 , 1.66812373])

# %%
# reset REGCV1 control parameters
ssa.REGCV1.set(
                src='M', 
                idx= ssa.REGCV1.idx.v,
                attr='v',
                value= M_base_IV
            )

ssa.REGCV1.set(
                src='D', 
                idx= ssa.REGCV1.idx.v, 
                attr='v',
                value= D_base_IV
            )
# Out:
# True

# %%
# reset power setting point
ssa.PV.set(
                src='p0', 
                idx= ssa.PV.idx.v, 
                attr='v',
                value= np.array([0.175 , 0.315 , 0.07  , 0.084 , 0.049 , 0.042 , 0.063 , 0.0525, 0.056 , 0.0595])
            )
# Out:
# True

# %%
# reset load
ssa.PQ.set(
                src='p0', 
                idx= ssa.PQ.idx.v, 
                attr='v',
                value= ssa.PQ.p0.v
            )
# Out:
# True

# %%
ssa.PFlow.run()

ssa.TDS.init()
# Out:
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: Off
#    Sparse solver: KLU
#  Solution method: NR method
# Power flow initialized in 0.0033 seconds.
# 0: |F(x)| = 0.65
# 1: |F(x)| = 0.003876638309
# 2: |F(x)| = 1.566892639e-05
# 3: |F(x)| = 8.199951829e-11
# Converged in 4 iterations in 0.0048 seconds.
# Initialization for dynamics completed in 0.0275 seconds.
# Initialization was successful.
# array([ 4.04127129e-01,  7.31904728e-01,  6.97650719e-01,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  9.62883616e-01,  8.13940862e-01,
#         8.49616903e-01,  2.95705413e-01,  5.78208861e-01,  5.36456595e-01,
#         9.29359915e-01,  7.27685398e-01,  7.71983856e-01,  3.78676589e-01,
#         6.94713632e-01,  6.44548595e-01,  1.75612667e-01,  3.17059460e-01,
#         2.94043980e-01,  1.75612667e-01,  3.17059460e-01,  2.94043980e-01,
#         1.10078008e+00,  1.18261341e+00,  1.18143557e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  2.09444245e-02, -3.83355257e-03,
#        -2.33947638e-03,  2.11538687e-01, -3.87188810e-02, -2.36287114e-02,
#         1.10078008e+00,  1.18261341e+00,  1.18143557e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  1.75612667e-01,  3.17059460e-01,
#         2.94043980e-01,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         1.75612667e-01,  3.17059460e-01,  2.94043980e-01,  1.75612667e-01,
#         3.17059460e-01,  2.94043980e-01,  1.75612667e-01,  3.17059460e-01,
#         2.94043980e-01, -3.51225334e-01, -6.34118921e-01, -5.88087960e-01,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -2.11109532e-02,
#        -4.53415831e-02, -6.32287448e-02, -3.45285416e-02, -3.47375023e-02,
#        -6.34821585e-02, -5.15362053e-02, -5.33006464e-02,  7.00000000e-02,
#         8.40000000e-02,  4.90000000e-02,  4.20000000e-02,  6.30000000e-02,
#         5.25000000e-02,  5.60000000e-02,  5.95000000e-02, -1.24933290e-03,
#        -7.99613711e-02, -9.24736526e-02, -1.00007213e-01, -1.83447847e-02,
#        -7.72713682e-02, -3.27835695e-02, -3.19866906e-02,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.
+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.75612667e-01,
#         3.17059460e-01,  2.94043980e-01,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.75612667e-01,  3.17059460e-01,  2.94043980e-01,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.75612667e-01,
#         3.17059460e-01,  2.94043980e-01,  1.75612667e-01,  3.17059460e-01,
#         2.94043980e-01,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.10078008e+00,  1.18261341e+00,  1.18143557e+00,  1.02094442e+00,
#         9.96166447e-01,  9.97660524e-01,  2.42171617e-01,  1.72599003e-02,
#         0.00000000e+00,  2.09444245e-02, -3.83355257e-03, -2.33947638e-03,
#         2.09444245e-02, -3.83355257e-03, -2.33947638e-03,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  1.75612667e-01,  3.17059460e-01,  2.94043980e-01,
#         1.75612667e-01,  3.17059460e-01,  2.94043980e-01,  1.75612667e-01,
#         3.17059460e-01,  2.94043980e-01,  1.75612667e-01,  3.17059460e-01,
#         2.94043980e-01, -3.51225334e-01, -6.34118921e-01, -5.88087960e-01,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  7.00000000e-02,  8.40000000e-02,  4.90000000e-02,
#         4.20000000e-02,  6.30000000e-02,  5.25000000e-02,  5.60000000e-02,
#         5.95000000e-02,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  7.00000000e-02,  8.40000000e-02,  4.90000000e-02,
#         4.20000000e-02,  6.30000000e-02,  5.25000000e-02,  5.60000000e-02,
#         5.95000000e-02,  1.24933290e-03,  7.99613711e-02,  9.24736526e-02,
#         1.00007213e-01,  1.83447847e-02,  7.72713682e-02,  3.27835695e-02,
#         3.19866906e-02,  7.00000000e-02,  8.40000000e-02,  4.90000000e-02,
#         4.20000000e-02,  6.30000000e-02,  5.25000000e-02,  5.60000000e-02,
#         5.95000000e-02, -1.24933290e-03, -7.99613711e-02, -9.24736526e-02,
#        -1.00007213e-01, -1.83447847e-02, -7.72713682e-02, -3.27835695e-02,
#        -3.19866906e-02,  7.00000000e-02,  8.40000000e-02,  4.90000000e-02,
#         4.20000000e-02,  6.30000000e-02,  5.25000000e-02,  5.60000000e-02,
#         5.95000000e-02, -1.24933290e-03, -7.99613711e-02, -9.24736526e-02,
#        -1.00007213e-01, -1.83447847e-02, -7.72713682e-02, -3.27835695e-02,
#        -3.19866906e-02,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  1.00012493e+00,  1.00799614e+00,  1.00924737e+00,
#         1.01000072e+00,  1.00183448e+00,  1.00772714e+00,  1.00327836e+00,
#         1.00319867e+00,  7.00000000e-03,  8.40000000e-03,  4.90000000e-03,
#         4.20000000e-03,  6.30000000e-03,  5.25000000e-03,  5.60000000e-03,
#         5.95000000e-03])

# %%
# Turn off stability check in TDS
ssa.TDS.config.criteria = 0

# Turn off simulation progress bar
ssa.TDS.config.no_tqdm = 1

# Simulation time
ssa.TDS.config.tf = 5

ssa.TDS.run()
# Out:
# -> Time Domain Simulation Summary:
# Sparse Solver: KLU
# Simulation time: 0.0-5 s.
# Fixed step size: h=33.33 ms. Shrink if not converged.
# <Toggle Toggler_1>: GENROU.GENROU_2 status changed to 0 at t=2.0 sec.
# Simulation to t=5.00 sec completed in 0.3717 seconds.
# True

# %%
# Turn off stability check in TDS
ssa.TDS.config.criteria = 0

# Turn off simulation progress bar
ssa.TDS.config.no_tqdm = 1

# Simulation time
ssa.TDS.config.tf = 20

ssa.TDS.run()
# Out:
# Simulation to t=20.00 sec completed in 0.8651 seconds.
# True

# %% [markdown]
# # Plot

# %%
ssa.TDS.plt.plot(
                ssa.Bus.v,
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
ssa.TDS.plt.plot(
                [ssa.REGCV1.omega, ssa.GENROU.omega],
                ytimes = 60,
                legend = True
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
ssa.TDS.plt.plot(
                [ssa.REGCV1.Pe, ssa.GENROU.Pe],
                # left = 0.5,
                # right = 5,
                legend = True
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
ssa.TDS.plt.plot(
                ssa.GENROU.Pe,
                # left = 0.5,
                # right = 5,
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %% [markdown]
# ## Extract data
#
# Code clariffication for extracting simulation data after TDS:
#
# ssa.dae.ts.y:  extract **algebra** variable
#
# ssa.dae.ts.x:  extract **state** variable
#
# ....a, .a means the idx of the target variable
#
# CHECK https://docs.andes.app/en/latest/groupdoc/SynGen.html#genrou for model reference

# %%
# Extract time
t = ssa.dae.ts.t
t = t[:, np.newaxis]

# Extract RoCoF
rocof     = ssa.dae.ts.y[:,  ssa.BusROCOF.Wf_y.a]
rocof_sg  = rocof[:, [0,1,2]]
rocof_ibr = rocof[:, [3,4,5,6,7,8,9,10]]
rocof_max = np.max(np.abs(rocof*60))

# Extract frequency
f         = ssa.dae.ts.x[:,  ssa.GENROU.omega.a]
fnadir    = np.min(f)*60 - 60

# Extract voltage
busV      = ssa.dae.ts.y[:,  ssa.Bus.v.a]
busV_min  = np.min(busV)

# Extract power angle
theta           = ssa.dae.ts.y[:, ssa.GENROU.a.a]
delta_theta     = np.max(theta, axis=1) - np.min(theta, axis=1)
delta_theta_max = np.max(delta_theta)

# %% [markdown]
# ## plot RoCoF

# %%
fig = plt.figure(figsize=(8, 3))
plt.subplots_adjust(left=None, bottom=None, right=None,
                    top=None, wspace=0.6, hspace=0.3)
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ibr_legend = ['IBR1','IBR2','IBR3','IBR4','IBR5','IBR6','IBR7','IBR8']
sg_legend = ['SG1', 'SG2', 'SG3']

ax1.plot(
            t,
            rocof_sg * 60,
        )
ax1.set_title('(a)')
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('RoCoF [Hz/s]')
ax1.legend(sg_legend)
# ax1.set_ylim([0.95, 1.12])
# ax1.set_xlim([0, 3600])

ax2.plot(
            t,
            rocof_ibr * 60,
        )
ax2.set_title('(b)')
ax2.set_xlabel('Time [s]')
ax2.set_ylabel('RoCoF [Hz/s]')
ax2.legend(ibr_legend)

# %% [markdown]
# ## Extract data after a specific time

# %%
# idx_t6 = np.min(np.where(t>6)[0])                      # find the idx of time t > 6
# f_t6   = ssa.dae.ts.x[idx_t6:,  ssa.GENROU.omega.a]    # extract the frequency after t = 6

# plt.plot(t[idx_t6:], f_t6)                             # plot the frequency after t = 6
