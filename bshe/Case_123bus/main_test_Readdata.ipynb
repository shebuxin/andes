# %%
import csv
import numpy as np
import ast

# %%
filename_input  = "input_10.csv"
filename_output = "output_10.csv"

# %%
# Read the output data from the CSV file into a NumPy array
input = np.genfromtxt(filename_input, delimiter=',')
input
# Out:
# array([[1.92729297e+00, 1.09086313e-01, 1.37165620e-01, 1.52047800e-02,
#         5.11821009e-03, 1.40205360e-02, 1.24020233e-02, 3.81612538e-03,
#         1.47005639e-02, 4.47633488e-03, 1.70949274e-03, 1.90688613e+00,
#         5.66833488e+00, 1.47508721e-01, 3.83580401e+00, 1.88701956e+00,
#         4.67716902e+00, 5.67525564e-01, 1.12824669e+00, 3.79683166e+00,
#         2.82184414e+00, 1.51916497e+00, 1.86842972e+00, 2.80184921e+00,
#         7.47679640e-01, 2.15835673e+00, 5.57188400e-01],
#        [5.70303788e-01, 1.64579332e-01, 7.81597066e-02, 1.53700318e-02,
#         5.65870865e-03, 5.37778123e-03, 7.82950503e-03, 2.04778778e-03,
#         1.84188708e-02, 1.51096305e-02, 5.14864604e-03, 4.26731510e+00,
#         2.20876500e-02, 5.79476660e+00, 4.22859912e+00, 1.50540806e+00,
#         5.01325416e+00, 2.56493744e+00, 5.15694347e+00, 2.23418546e+00,
#         1.21375603e+00, 1.05760926e+00, 1.99314505e+00, 1.59668824e+00,
# ...

# %%
input.shape
# Out:
# (10, 27)

# %%
# Read the output data from the CSV file into a NumPy array
output = np.genfromtxt(filename_output, delimiter=',')
output
# Out:
# array([[ 1.31606934e+01, -2.32633653e+00,  1.29036086e+00,
#         -2.03081446e-12,  5.00441507e+00,  5.00441507e+00],
#        [ 6.45520760e+01,  3.05163877e-03,  5.42409323e+00,
#         -3.40088164e-14,  3.24283631e+01,  3.24283631e+01],
#        [ 2.31910246e+01, -2.49335562e+00,  7.61796360e+00,
#         -9.48455154e-12,  1.87834004e-01,  1.87834004e-01],
#        [ 2.94142703e+01, -8.02566914e-02,  3.10074530e+00,
#         -4.06944167e-11,  1.02027704e+01,  1.02027704e+01],
#        [ 1.77622465e+01, -2.29427590e-01,  5.60584499e+00,
#         -1.07725297e-10,  1.06081978e+01,  1.06081978e+01],
#        [ 5.64458239e+01, -3.33027332e+00,  1.29574798e+00,
#         -5.03498197e-01,  1.16121101e+01,  1.16121101e+01],
#        [ 1.59571626e+01, -1.11788200e+00,  2.10634274e+00,
#         -1.70477511e-11,  1.34044774e+01,  1.34044774e+01],
#        [ 2.57135868e+01, -3.13346741e+00,  2.28254298e+00,
#         -4.59179071e-11,  3.85969813e-02,  3.85969813e-02],
# ...

# %%
output.shape
# Out:
# (10, 6)
