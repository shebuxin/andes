# %%
import andes
import os
import matplotlib.pyplot as plt
# import matplotlib 
# %matplotlib inline
import numpy as np

# %% [markdown]
# # Load case

# %%
andes.config_logger(stream_level=20)

# case path
dir_path = os.path.abspath('..')
loc_path_case1 = '/Case_123bus/case123_REGCV1.xlsx'
loc_path_case2 = '/Case_123bus/case123_REGCV1_v2.xlsx'
loc_path_case3 = '/Case_123bus/case123_REGCV1_v3.xlsx'
loc_path_case4 = '/Case_123bus/case123_REGCV1_v4.xlsx'

case = dir_path + loc_path_case4

# load a case
ssa = andes.load(case,
                 setup=True,
                 no_output=True)
# Out:
# Working directory: "/home/buxin/andes/bshe/Case_123bus"
# > Loaded config from file "/home/buxin/.andes/andes.rc"
# > Reloaded generated Python code of module "pycode".
# Parsing input file "/home/buxin/andes/bshe/Case_123bus/case123_REGCV1_v4.xlsx"...
# Input file parsed in 0.0826 seconds.
# System internal structure set up in 0.0262 seconds.

# %%
ssa.PFlow.run()
# Out:
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: Off
#    Sparse solver: KLU
#  Solution method: NR method
# Power flow initialized in 0.0047 seconds.
# 0: |F(x)| = 0.8
# 1: |F(x)| = 0.0005057156877
# 2: |F(x)| = 2.592582604e-07
# Converged in 3 iterations in 0.0045 seconds.
# True

# %%
# reset control parameters
# ssa.REGCV1.set(
#                 src='M', 
#                 idx= ssa.REGCV1.idx.v,
#                 attr='v',
#                 value= vsg_res['Mvsg']
#             )

# ssa.REGCV1.set(
#                 src='D', 
#                 idx= ssa.REGCV1.idx.v, 
#                 attr='v',
#                 value= vsg_res['Dvsg']
#             )

# %%
ssa.TDS.init()
# Out:
# Initialization for dynamics completed in 0.0474 seconds.
# Initialization was successful.
# array([ 1.79511074e-01,  1.75580089e-01,  1.90851166e-01,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.01827276e+00,  1.00552287e+00,
#         9.92731361e-01,  1.30081617e-01,  1.56726598e-01,  1.57950697e-01,
#         9.88395417e-01,  9.83858405e-01,  9.83391868e-01,  1.66580863e-01,
#         1.88305838e-01,  1.89776583e-01,  8.01759668e-02,  8.01450284e-02,
#         7.60209171e-02,  8.01759668e-02,  8.01450284e-02,  7.60209171e-02,
#         1.14117029e+00,  1.09812097e+00,  1.03265016e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  2.27169114e-02, -4.61834263e-03,
#        -2.04485180e-03,  2.29440805e-01, -4.66452606e-02, -2.06530032e-02,
#         1.14117029e+00,  1.09812097e+00,  1.03265016e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  8.01759668e-02,  8.01450284e-02,
#         7.60209171e-02,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         8.01759668e-02,  8.01450284e-02,  7.60209171e-02,  8.01759668e-02,
#         8.01450284e-02,  7.60209171e-02,  8.01759668e-02,  8.01450284e-02,
#         7.60209171e-02, -1.60351934e-01, -1.60290057e-01, -1.52041834e-01,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -7.15102323e-03,
#        -1.43320078e-02, -1.89920700e-02, -1.03990659e-02, -1.47631531e-02,
#        -2.07390641e-02, -1.76230433e-02, -1.86385570e-02,  1.50000000e-02,
#         1.50000000e-02,  1.50000000e-02,  1.50000000e-02,  1.50000000e-02,
#         1.50000000e-02,  1.50000000e-02,  1.50000000e-02, -1.21438444e-02,
#        -4.44350111e-02, -4.68786106e-02, -3.52050769e-02, -1.53171024e-02,
#        -3.33904513e-02, -1.69297314e-02, -1.81149440e-02,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.
+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  8.01759668e-02,
#         8.01450284e-02,  7.60209171e-02,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  8.01759668e-02,  8.01450284e-02,  7.60209171e-02,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  8.01759668e-02,
#         8.01450284e-02,  7.60209171e-02,  8.01759668e-02,  8.01450284e-02,
#         7.60209171e-02,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.14117029e+00,  1.09812097e+00,  1.03265016e+00,  1.02271691e+00,
#         9.95381657e-01,  9.97955148e-01,  2.51057464e-01,  7.52265726e-03,
#         0.00000000e+00,  2.27169114e-02, -4.61834263e-03, -2.04485180e-03,
#         2.27169114e-02, -4.61834263e-03, -2.04485180e-03,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  8.01759668e-02,  8.01450284e-02,  7.60209171e-02,
#         8.01759668e-02,  8.01450284e-02,  7.60209171e-02,  8.01759668e-02,
#         8.01450284e-02,  7.60209171e-02,  8.01759668e-02,  8.01450284e-02,
#         7.60209171e-02, -1.60351934e-01, -1.60290057e-01, -1.52041834e-01,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  1.50000000e-02,  1.50000000e-02,  1.50000000e-02,
#         1.50000000e-02,  1.50000000e-02,  1.50000000e-02,  1.50000000e-02,
#         1.50000000e-02,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  1.50000000e-02,  1.50000000e-02,  1.50000000e-02,
#         1.50000000e-02,  1.50000000e-02,  1.50000000e-02,  1.50000000e-02,
#         1.50000000e-02,  1.21438444e-02,  4.44350111e-02,  4.68786106e-02,
#         3.52050769e-02,  1.53171024e-02,  3.33904513e-02,  1.69297314e-02,
#         1.81149440e-02,  1.50000000e-02,  1.50000000e-02,  1.50000000e-02,
#         1.50000000e-02,  1.50000000e-02,  1.50000000e-02,  1.50000000e-02,
#         1.50000000e-02, -1.21438444e-02, -4.44350111e-02, -4.68786106e-02,
#        -3.52050769e-02, -1.53171024e-02, -3.33904513e-02, -1.69297314e-02,
#        -1.81149440e-02,  1.50000000e-02,  1.50000000e-02,  1.50000000e-02,
#         1.50000000e-02,  1.50000000e-02,  1.50000000e-02,  1.50000000e-02,
#         1.50000000e-02, -1.21438444e-02, -4.44350111e-02, -4.68786106e-02,
#        -3.52050769e-02, -1.53171024e-02, -3.33904513e-02, -1.69297314e-02,
#        -1.81149440e-02,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  1.00121438e+00,  1.00444350e+00,  1.00468786e+00,
#         1.00352051e+00,  1.00153171e+00,  1.00333905e+00,  1.00169297e+00,
#         1.00181149e+00,  1.50000000e-03,  1.50000000e-03,  1.50000000e-03,
#         1.50000000e-03,  1.50000000e-03,  1.50000000e-03,  1.50000000e-03,
#         1.50000000e-03])

# %%
# Turn off stability check in TDS
ssa.TDS.config.criteria = 0

# Turn off simulation progress bar
ssa.TDS.config.no_tqdm = 1

ssa.TDS.config.tf = 15

ssa.TDS.run()
# Out:
# -> Time Domain Simulation Summary:
# Sparse Solver: KLU
# Simulation time: 0.0-15 s.
# Fixed step size: h=33.33 ms. Shrink if not converged.
# <Toggle Toggler_1>: GENROU.GENROU_2 status changed to 0 at t=5.0 sec.
# Simulation to t=15.00 sec completed in 1.1422 seconds.
# True

# %% [markdown]
# # Plot

# %%
ssa.TDS.plt.plot(
                ssa.Bus.v
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
ssa.TDS.plt.plot(
                ssa.Bus.v,
                # ymin = ...,
                # ymax = ...,
                left = 4.99,
                right = 5.01,
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
ssa.TDS.plt.plot(
                ssa.REGCV1.omega,
                ytimes = 60
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
ssa.TDS.plt.plot(
                ssa.GENROU.omega,
                ytimes = 60
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
# connected bus angle
# ssa.TDS.plt.plot(
#                 ssa.GENROW.a,
#                 )

# IBR voltage
ssa.TDS.plt.plot(
                ssa.REGCV1.delta,
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
ssa.TDS.plt.plot(
                ssa.BusROCOF.Wf_y,
                ytimes = 60
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %% [markdown]
# ## Plot RoCoF

# %%
t = ssa.dae.ts.t
t = t[:, np.newaxis]

rocof     = ssa.dae.ts.y[:,  ssa.BusROCOF.Wf_y.a]
rocof_sg  = rocof[:, [0,1,2]]
rocof_ibr = rocof[:, [3,4,5,6,7,8,9,10]]

# %%
np.max(np.abs(rocof*60))
# Out:
# 0.04762410408111734

# %%
fig = plt.figure(figsize=(8, 3))
plt.subplots_adjust(left=None, bottom=None, right=None,
                    top=None, wspace=0.6, hspace=0.3)
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ibr_legend = ['IBR1','IBR2','IBR3','IBR4','IBR5','IBR6','IBR7','IBR8']
sg_legend = ['SG1', 'SG2', 'SG3']

ax1.plot(
            t,
            rocof_sg * 60,
        )
ax1.set_title('(a)')
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('RoCoF [Hz/s]')
ax1.legend(sg_legend)
# ax1.set_ylim([0.95, 1.12])
# ax1.set_xlim([0, 3600])

ax2.plot(
            t,
            rocof_ibr * 60,
        )
ax2.set_title('(b)')
ax2.set_xlabel('Time [s]')
ax2.set_ylabel('RoCoF [Hz/s]')
ax2.legend(ibr_legend)

# %%
fig_gen, ax_gen = plt.subplots(1, 2, figsize=(8, 4))

plt.subplots_adjust(left=None, bottom=None, right=None,
                    top=None, wspace=0.3, hspace=0.25)

# ---- sg rocof ----
ax_gen[0, 0].plot(
                    t,
                    rocof_sg,
                )
ax_gen[0, 0].set_title('(a)')
ax_gen[0, 0].set_xlabel('Time [s]')
ax_gen[0, 0].set_ylabel('RoCoF [Hz/s]')
ax_gen[0, 0].legend(sg_legend)
# ax_gen[0, 0].set_ylim([0.95, 1.12])
# ax_gen[0, 0].set_xlim([0, 3600])

# ---- sg freq ----
ax_gen[0, 1].plot(
                    t,
                    rocof_ibr
                )
ax_gen[0, 1].set_title('(b)')
ax_gen[0, 1].set_xlabel('Time [s]')
ax_gen[0, 1].set_ylabel('RoCoF [Hz/s]')
ax_gen[0, 1].legend(ibr_legend)
# ax_gen[0, 1].set_ylim([0.95, 1.12])
# ax_gen[0, 1].set_xlim([0, 3600])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[536], line 7
#       3 plt.subplots_adjust(left=None, bottom=None, right=None,
#       4                     top=None, wspace=0.3, hspace=0.25)
#       6 # ---- sg rocof ----
# ----> 7 ax_gen[0, 0].plot(
#       8                     t,
#       9                     rocof_sg,
#      10                 )
#      11 ax_gen[0, 0].set_title('(a)')
#      12 ax_gen[0, 0].set_xlabel('Time [s]')
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
t.shape
# Out:
# (457, 1)

# %%
rocof_sg.shape
# Out:
# (457, 3)
