# %%
import os
import andes
import numpy as np
import pandas as pd
import pandapower as pp
import matplotlib.pyplot as plt
import scipy.stats as stat

from andes.interop.pandapower import to_pandapower, runopp_map
from andes.interop.pandapower import add_gencost, build_group_table
andes.config_logger(stream_level=20)
from math import ceil, floor

# virtual inertia scheduling class
from pdpower import make_link_table
from visopf import vis2_tds, loadnn

# function for main
from vistds import get_andes_case, get_load, disturbance

# %% [markdown]
# # TDS for VIS

# %% [markdown]
# ## ini andes attribute

# %%
# ini andes attribute
case_path = '/VIS_opf/ieee39_vis_tds.xlsx'
ssa = get_andes_case(case_path)
ssa.TDS.config.no_tqdm = 1 # trun off tds progress fig to speed up sim

# ini load
ptotal = ssa.PQ.as_df()['p0'].sum()
gentotal = ssa.PV.as_df()['Sn'].sum() + ssa.Slack.as_df()['Sn'].sum()
gentotal /= ssa.config.mva
l_rate = ptotal/gentotal

print(f'Gen capacity is: {gentotal} p.u.\
        \nInitial load is: {ptotal.round(4)} p.u.\
        \ninitial load rate is {l_rate*100} %' )
# Out:
# Working directory: "/home/bshe/repos/andes/bshe/VIS_opf"
# > Loaded config from file "/home/bshe/.andes/andes.rc"
# > Loaded generated Python code in "/home/bshe/.andes/pycode".
# Parsing input file "/home/bshe/repos/andes/bshe/VIS_opf/ieee39_vis_tds.xlsx"...
# Input file parsed in 0.0910 seconds.
# ACEc <1> added BusFreq <BusFreq_17> linked to bus <1>
# System internal structure set up in 0.0414 seconds.
# Gen capacity is: 109.389 p.u.
# Initial load is: 58.564 p.u.
# initial load rate is 53.537375787327804 %

# %%
# load profile
data_path = '/VIS_opf/dsyn.csv'
d_syn, load_pic, dpe = get_load(data_path, load_time=10, l_rate=l_rate, scale=1.2)
dpe
# Out:
# array([0.03565793, 0.01084198, 0.02528576, 0.03060994, 0.04176422,
#        0.04366409, 0.03213357, 0.02575858, 0.03593427, 0.04595194,
#        0.0406058 , 0.03794242])

# %% [markdown]
# # ini visopf instance

# %%
# get neural network data
nn_path = '/VIS_opf/NN_train'
nn, norm = loadnn(nn_path)

# ini visopf attribute
ssvis = vis2_tds(norm=norm, nn=nn, dpe=0, rocof_lim=0.033, nadir_lim=0.01)

# set vsg gen
vsg_ieee39 = ['PV_1', 'PV_6', 'PV_8', 'PV_9']

# load from andes
ssvis.from_andes(ssa, vsg_ieee39, Sbase=1000)

# add gen cost:
# Note: if two gens have the same cost, optimization results of
#       pandapower and gurobipy may be different.
linearcost = [
                0.5,   # PV_1 vsg
                1, 
                1.5,
                0.8, 
                0.8, 
                1,     # PV_6 vsg
                1, 
                0.6,   # PV_8 vsg
                0.5,   # PV_9 vsg 
                1.5    # slack
            ]

# set up cost
ssvis.cost['c1'] = linearcost
ssvis.update_dict()
# Out:
# Restricted license - for non-production use only - expires 2023-10-25
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: Off
#    Sparse solver: KLU
#  Solution method: NR method
# Power flow initialized in 0.0053 seconds.
# 0: |F(x)| = 7.561249598
# 1: |F(x)| = 2.916162515
# 2: |F(x)| = 0.1315330771
# 3: |F(x)| = 0.0003398595952
# 4: |F(x)| = 4.189813829e-09
# Converged in 5 iterations in 0.0084 seconds.
# Power flow results are consistent. Conversion is successful.
# GSF is consistent.
# Note: Control (dynamic) parameters are renormalized based on case Sbase rather then to andes base

# %% [markdown]
# # ini pandapower instance

# %%
# convert andes to a pandapower instance
ssp = to_pandapower(ssa)

# set up pandapower gen cost
gen_cost = np.array([[2., 0., 0., 3., 0., 0., 0.]] * ssp.gen.shape[0])
gen_cost[:, 5] = linearcost  # c1

add_gencost(ssp, gen_cost)
# Out:
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: Off
#    Sparse solver: KLU
#  Solution method: NR method
# Power flow initialized in 0.0062 seconds.
# 0: |F(x)| = 7.561249598
# 1: |F(x)| = 2.916162515
# 2: |F(x)| = 0.1315330771
# 3: |F(x)| = 0.0003398595952
# 4: |F(x)| = 4.189813829e-09
# Converged in 5 iterations in 0.0084 seconds.
# Power flow results are consistent. Conversion is successful.
# True

# %% [markdown]
# ### make link table between pandapower and andes

# %%
# --- link pandapower output to andes key ---
ssa_key = make_link_table(ssa)

# make index table to change pandapower and andes setting point
# pandapwoer uses dataframe index, i.g. 0, 1, 2 ....
# andes uses idx to call variable

# --- add controllable in the link table ---
ssa_bus = ssa.Bus.as_df().reset_index().rename(columns={'uid':'bus_pp', 'idx':'bus_idx'})
ssp_gen = ssp.gen.reset_index().rename(columns={'index':'gen_pp', 'name':'stg_idx', 'controllable':'ctrl'})

ssa_key2 = pd.merge(
                        left=ssa_key,
                        right=ssp_gen[['stg_idx', 'gen_pp', 'ctrl']],
                        on='stg_idx', 
                        how='left'
                    )

# --- device idx ---
# use to set andes setting point
ssa_dg_idx = ssa_key2.dg_idx.dropna().tolist()   
ssa_syg_idx = ssa_key2.syg_idx.dropna().tolist()
ssa_gov_idx = ssa_key2.gov_idx.dropna().tolist() 
ssa_stg_idx = ssa_key2.stg_idx.dropna().tolist() # static gen
ssa_rg_idx = ssa_key2.rg_idx.dropna().tolist()   # renewable gen: vsg

# --- online and controllable device idx ---
ctrl_cond = ssa_key2.ctrl & ssa_key2.stg_u.astype(bool)

ssa_dg_idx_ctrl = ssa_key2.dg_idx[ctrl_cond].dropna().tolist()
ssa_syg_idx_ctrl = ssa_key2.syg_idx[ctrl_cond].dropna().tolist()
ssa_gov_idx_ctrl = ssa_key2.gov_idx[ctrl_cond].dropna().tolist()
ssa_stg_idx_ctrl = ssa_key2.stg_idx[ctrl_cond].dropna().tolist()

# fill NaN with False
ssa_key2.fillna(value=False, inplace=True)

# %% [markdown]
# ## TDS parameters

# %%
# --- TDS Constants ---
t_total = 3600  # total simulation time

# update interval
intv_ed = 300   # RTED
intv_agc = 4    # AGC
intv_pq = 1     # PQ load
intv_step = 100 # step change to smooth the setpoitns

# number of intervals
n_ed = int(t_total/intv_ed)
n_agc = int(intv_ed/intv_agc)
n_pq = int(intv_agc/intv_pq)
n_step = floor(intv_step/intv_agc)

# --- TDS vars ---
# AGC table
agc_table = ssp.gen[['name']].rename(columns={'name':'stg_idx'})
agc_table['paux'] = 0
agc_res = agc_table[['stg_idx']].copy()

# ACE vars for PI controller
ACE_integral = 0
ACE_raw = 0
Kp = 0.2 # 0.05
Ki = 0.1
ace_res = pd.DataFrame()

# initial load value
ssa_p0 = ssa.PQ.p0.v.copy()
ssa_q0 = ssa.PQ.q0.v.copy()
ssa_pq_idx = ssa.PQ.idx.v
ssa_p0_sum = ssa_p0.sum()

# %%
# Reserve some capacity to avoid TDS crush
ssp.gen.max_p_mw = 1 * ssp.gen.max_p_mw # for AC

# store original generator data
ssp_gen0 = ssp.gen.copy()

for time in range(t_total):  # t_total

    # ----------------------- RTED (VIS opf) interval -------------------------
    if time % intv_ed == 0:
        """
            RTED update with vis opf

            attributes:
            ----------
            - 01 get disturbance
            - 02 update visopf instance
            - 03 update pandapower instance
            - 04 update andes instance
        """
        # --- 01 get disturbance ---
        idx_ed = time // intv_ed
        load, dpe, dvsg_capacity = disturbance(d_syn, idx_ed, intv_ed)

        # --- 02 update visopf instance ---
        # load
        ssvis.load['p0'] = ssa_p0 * load # visopf load update
        # dpe
        ssvis.dpe = dpe
        # vsg gen capacity
        # TODO ... update vsg gen capacity of visopf

        ssvis.update_dict()

        # solve visopf
        visres, vsg_res, _ = ssvis.get_res() 

        # --- 03 update pandapwoer instance ---
        # load
        ssp.load.scaling = load
        # pandapower gen
        ssp_gen = pd.merge(
                            left=ssp.gen.rename(columns={'name': 'stg_idx'}),
                            right=visres.rename(columns={'gen': 'stg_idx'}),
                            on='stg_idx',
                            how='left'
                        )

        # vsg power reserve limits
        # TODO: integrate delta vsg capacity change here
        ssp_gen['vsg_up'] = ssp_gen.max_p_mw - ssp_gen.pru * ssp.sn_mva
        ssp_gen['vsg_d'] = ssp_gen.min_p_mw + ssp_gen.prd * ssp.sn_mva

        ssp.gen.max_p_mw = ssp_gen['vsg_up']
        ssp.gen.min_p_mw = ssp_gen['vsg_d']

        # run pandapower ACOPF, modify setpoints
        # store setpoints
        if time > 0:
            p0 = ssp_res['p'].values        # store setpoints
        else:
            p0 = [0] * ssa_key2.shape[0]

        # solve ACOPF
        ssp_res = runopp_map(ssp, ssa_key)  # ACOPF resutls
        ssp_res['p0'] = p0                  # last setpoints
        ssp_res.fillna(False, inplace=True) # Fill NA wil False

        # reset Generator limtis to normal limits
        # TODO: integrate delta vsg capacity change here
        ssp.gen.max_p_mw = ssp_gen0.max_p_mw
        ssp.gen.min_p_mw = ssp_gen0.min_p_mw

        # --- 04 update andes instance ---
        ssa.REGCV1.set(
                        src='M', 
                        idx= ssa.REGCV1.idx.v,
                        attr='v',
                        value= vsg_res['Mvsg']
                    )
        ssa.REGCV1.set(
                        src='D', 
                        idx= ssa.REGCV1.idx.v, 
                        attr='v',
                        value= vsg_res['Dvsg']
                    )

    # ---------------------- AGC interval -------------------------
    """
        AGC update

        attributes:
        ----------
        - 01 assign ACE signla to gen 
        - 02 smooth setpoints
    """
    ace_gain = 1

    if time % intv_agc == 0:
        idx_agc = time // intv_agc - idx_ed * n_agc
        # --- 01 allocate AGC ---

        # ACE_raw > 0: assign to expensive gen
        # ACE_raw < 0: assign to cheap gen
        # Note: allocate to synchronous generator governors
        if ACE_raw > 0:
            agc_idx = ['TGOV1_10', 'TGOV1_2'] # TODO: change to expensive gen
        else:
            agc_idx = ['TGOV1_4', 'TGOV1_5'] # TODO: change to cheap gen

        ssa.TurbineGov.set(
                            src='paux0',
                            idx= agc_idx,
                            attr='v',
                            value= ACE_raw/len(agc_idx) # allocate equally to each agc gen
                        )

        # --- smooth setpoints ---
        if idx_ed == 0:
            ssp_res['pref'] = ssp_res['p']
        else:
            idx_step = min((time - idx_ed * intv_ed) // intv_agc + 1, n_step)

            ssp_res['pref_step'] = ssp_res.p - ssp_res.p0
            # smooth change threshold: 0.1
            # check ssp_res format for vsg setpoints
            large_index = ssp_res['pref_step'][abs(ssp_res['pref_step']) > 0.01].index
            ssp_res['pref_delta'] = ssp_res['pref_step']
            ssp_res['pref_delta'].iloc[large_index] = ssp_res['pref_step'].iloc[large_index] / n_step * idx_step
            ssp_res['pref'] = ssp_res.p0 + ssp_res.pref_delta

            # update SynGen setpoints
            cond_gov = ssp_res.controllable & ssp_res.gov_idx.astype(bool)
            ssa.TurbineGov.set(
                                src='pref0', 
                                idx=ssp_res.gov_idx[cond_gov].tolist(),
                                attr='v',
                                value=ssp_res.pref[cond_gov].values
                            )

            # update DG setpoints
            cond_dg = ssp_res.controllable & ssp_res.dg_idx.astype(bool)
            ssa.DG.set(
                        src='pref0', 
                        idx=ssp_res.dg_idx[cond_dg].tolist(),
                        attr='v', 
                        value=ssp_res.pref[cond_dg].values
                    )
                    
            # update vsg setpoints
            cond_rg = ssp_res.controllable & ssp_res.rg_idx.astype(bool)
            ssa.RenGen.set(
                                src='Pref', 
                                idx=ssp_res.rg_idx[cond_rg].tolist(),
                                attr='v',
                                value=ssp_res.pref[cond_rg].values
                            )

    # ----------------------- load change interval ----------------------
    """
        load change 

        attributes:
        ----------
        - 01 update load
        - 02 run TDS
    """
    # Initially, alter StaticGen: p0 and q0, RUN power flow
    # Otherwise, alter Ppf and Qpf
    if time == 0:
        # get idx from pandapower results
        stg_opf_idx = ssp_res.stg_idx[ssp_res.controllable].tolist()
        stg_opf_val = ssp_res.p[ssp_res.controllable].tolist()
        stg_opf_v = ssp_res.vm_pu[ssp_res.controllable].tolist()

        ssa.StaticGen.set(
                            src='p0',
                            idx=stg_opf_idx,
                            attr='v',
                            value=stg_opf_val
                        )
        ssa.StaticGen.set(
                            src='v0', 
                            idx=stg_opf_idx, 
                            attr='v', 
                            value=stg_opf_v
                        )

        # initial load point set as the dispatch point
        ssa.PQ.set(
                    src='p0', 
                    idx=ssa_pq_idx, 
                    attr='v',
                    value=ssa_p0 * load
                )
        ssa.PQ.set(
                    src='q0', 
                    idx=ssa_pq_idx, 
                    attr='v',
                    value=ssa_q0 * load
                )
        ssa.PFlow.run()
    else:
        ssa.PQ.set(
                    src='Ppf', 
                    idx=ssa_pq_idx, 
                    attr='v',
                    value=ssa_p0 * d_syn['sload'].iloc[time]
                )
        ssa.PQ.set(
                    src='Qpf', 
                    idx=ssa_pq_idx, 
                    attr='v',
                    value=ssa_q0 * d_syn['sload'].iloc[time]
                )

    # ----------------------- run TDS, cal ACE ----------------------
    # run TDS
    ssa.TDS.config.tf = time
    if time == 0:
        ssa.TDS.init()
        ACE_raw = 0 # delete when run TDS ???
    ssa.TDS.run()

    # update AGC using PI Controller
    ACE_integral += ssa.ACEc.ace.v.sum()
    ACE_raw = -( Kp * ssa.ACEc.ace.v.sum() + Ki * ACE_integral )

   # ----------------------- TDS error break ----------------------
    if ssa.exit_code != 0:
        raise ValueError(f"TDS error! Exit with {ssa.exit_code}, end at {time} s.")
# Out:
# Successfully build var.
# Successfully build obj.
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Successfully build cons.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1040 rows, 678 columns and 11118 nonzeros
# Model fingerprint: 0x216d2c7d
# Variable types: 358 continuous, 320 integer (320 binary)
# Coefficient statistics:
#   Matrix range     [4e-06, 1e+02]
#   Objective range  [5e-01, 2e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [7e-03, 2e+03]
# Found heuristic solution: objective 56.1005313
# Presolve removed 764 rows and 483 columns
# Presolve time: 0.01s
# Presolved: 276 rows, 195 columns, 3084 nonzeros
# Variable types: 106 continuous, 89 integer (89 binary)
#
# Root relaxation: objective 4.927566e+01, 127 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   49.27566    0    1   56.10053   49.27566  12.2%     -    0s
# H    0     0                      49.2756641   49.27566  0.00%     -    0s
#      0     0   49.27566    0    1   49.27566   49.27566  0.00%     -    0s
#
# Explored 1 nodes (127 simplex iterations) in 0.04 seconds (0.01 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 49.2757 56.1005
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.927566414163e+01, best bound 4.927566414163e+01, gap 0.0000%
# Msys and Dsys are normlized by devise Sbase, transform to andes Sbase when do TDS
# --------------------- Results -------------------
# Total Cost: 49.2757
# RoCof prediction: 0 ; RoCof limit: 0.033
# Nadir prediction: -0 ; Nadir limit 0.01
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: Off
#    Sparse solver: KLU
#  Solution method: NR method
# Power flow initialized in 0.0062 seconds.
# 0: |F(x)| = 8.038378387
# 1: |F(x)| = 3.739190695
# 2: |F(x)| = 0.2305305034
# 3: |F(x)| = 0.001641938032
# 4: |F(x)| = 1.039733659e-07
# Converged in 5 iterations in 0.0086 seconds.
# GENROU (xl <= xd2) out of typical upper limit.
#
#    idx     | values | limit
# -----------+--------+------
#  GENROU_2  | 0.042  | 0.036
#  GENROU_3  | 0.036  | 0.003
#  GENROU_4  | 0.025  | 0.001
#  GENROU_5  | 0.050  | 0.001
#  GENROU_7  | 0.031  | 0.002
#  GENROU_10 | 0.003  | 0.000
#
#
# Initialization for dynamics completed in 0.0587 seconds.
# Initialization was successful.
#
# -> Time Domain Simulation Summary:
# Sparse Solver: KLU
# Simulation time: 0.0-0 s.
# Fixed step size: h=33.33 ms. Shrink if not converged.
# Simulation to t=0.00 sec completed in 0.0000 seconds.
#
# -> Time Domain Simulation Summary:
# Sparse Solver: KLU
# Simulation time: 0.0-1 s.
# Fixed step size: h=33.33 ms. Shrink if not converged.
# Current step size is zero. Integration is not permitted.
# Simulation to t=1.00 sec completed in 0.0736 seconds.
# Simulation to t=2.00 sec completed in 0.0664 seconds.
# Simulation to t=3.00 sec completed in 0.0689 seconds.
# Simulation to t=4.00 sec completed in 0.0684 seconds.
# Simulation to t=5.00 sec completed in 0.0714 seconds.
# Simulation to t=277.00 sec completed in 0.0814 seconds.
# Simulation to t=278.00 sec completed in 0.0802 seconds.
# Simulation to t=279.00 sec completed in 0.0764 seconds.
# Simulation to t=280.00 sec completed in 0.0903 seconds.
# Simulation to t=281.00 sec completed in 0.0855 seconds.
# Simulation to t=282.00 sec completed in 0.0847 seconds.
# Simulation to t=283.00 sec completed in 0.0803 seconds.
# Simulation to t=284.00 sec completed in 0.0945 seconds.
# Simulation to t=285.00 sec completed in 0.0874 seconds.
# Simulation to t=286.00 sec completed in 0.0902 seconds.
# Simulation to t=287.00 sec completed in 0.0856 seconds.
# Simulation to t=288.00 sec completed in 0.1046 seconds.
# Simulation to t=289.00 sec completed in 0.0934 seconds.
# Simulation to t=290.00 sec completed in 0.0960 seconds.
# Simulation to t=291.00 sec completed in 0.0892 seconds.
# Simulation to t=292.00 sec completed in 0.1125 seconds.
# Simulation to t=293.00 sec completed in 0.1078 seconds.
# Simulation to t=294.00 sec completed in 0.1072 seconds.
# Simulation to t=295.00 sec completed in 0.0959 seconds.
# Simulation to t=296.00 sec completed in 0.1151 seconds.
# Simulation to t=297.00 sec completed in 0.1142 seconds.
# Simulation to t=298.00 sec completed in 0.1136 seconds.
# Simulation to t=299.00 sec completed in 0.1012 seconds.
# Successfully build var.
# Successfully build obj.
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Successfully build cons.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1040 rows, 678 columns and 11758 nonzeros
# Model fingerprint: 0x3a1a39e8
# Variable types: 358 continuous, 320 integer (320 binary)
# Coefficient statistics:
#   Matrix range     [9e-08, 1e+02]
#   Objective range  [5e-01, 2e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [6e-03, 2e+03]
# Found heuristic solution: objective 52.5499933
# Presolve removed 692 rows and 418 columns
# Presolve time: 0.01s
# Presolved: 348 rows, 260 columns, 4325 nonzeros
# Variable types: 171 continuous, 89 integer (89 binary)
#
# Root relaxation: objective 4.664999e+01, 129 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   46.64999    0    5   52.54999   46.64999  11.2%     -    0s
# H    0     0                      46.6499933   46.64999  0.00%     -    0s
#      0     0   46.64999    0    5   46.64999   46.64999  0.00%     -    0s
#
# Explored 1 nodes (129 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 46.65 52.55
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.664999331779e+01, best bound 4.664999331779e+01, gap 0.0000%
# Msys and Dsys are normlized by devise Sbase, transform to andes Sbase when do TDS
# --------------------- Results -------------------
# Total Cost: 46.65
# RoCof prediction: -0.00858806 ; RoCof limit: 0.033
# Nadir prediction: 0.00133855 ; Nadir limit 0.01
# Simulation to t=300.00 sec completed in 0.1148 seconds.
# Simulation to t=301.00 sec completed in 0.1061 seconds.
# Simulation to t=302.00 sec completed in 0.0979 seconds.
# Simulation to t=303.00 sec completed in 0.0990 seconds.
# Simulation to t=304.00 sec completed in 0.1193 seconds.
# Simulation to t=305.00 sec completed in 0.1140 seconds.
# Simulation to t=306.00 sec completed in 0.0985 seconds.
# Simulation to t=307.00 sec completed in 0.0975 seconds.
# Simulation to t=308.00 sec completed in 0.1182 seconds.
# Simulation to t=309.00 sec completed in 0.1129 seconds.
# Simulation to t=310.00 sec completed in 0.1151 seconds.
# Simulation to t=311.00 sec completed in 0.1149 seconds.
# Simulation to t=584.00 sec completed in 0.0691 seconds.
# Simulation to t=585.00 sec completed in 0.0692 seconds.
# Simulation to t=586.00 sec completed in 0.0692 seconds.
# Simulation to t=587.00 sec completed in 0.0689 seconds.
# Simulation to t=588.00 sec completed in 0.0706 seconds.
# Simulation to t=589.00 sec completed in 0.0694 seconds.
# Simulation to t=590.00 sec completed in 0.0692 seconds.
# Simulation to t=591.00 sec completed in 0.0692 seconds.
# Simulation to t=592.00 sec completed in 0.0696 seconds.
# Simulation to t=593.00 sec completed in 0.0692 seconds.
# Simulation to t=594.00 sec completed in 0.0697 seconds.
# Simulation to t=595.00 sec completed in 0.0697 seconds.
# Simulation to t=596.00 sec completed in 0.0692 seconds.
# Simulation to t=597.00 sec completed in 0.0693 seconds.
# Simulation to t=598.00 sec completed in 0.0693 seconds.
# Simulation to t=599.00 sec completed in 0.0694 seconds.
# Successfully build var.
# Successfully build obj.
# Warning for adding constraints: zero or small (< 1e-13) coefficients, ignored
# Successfully build cons.
# Gurobi Optimizer version 9.5.1 build v9.5.1rc2 (linux64)
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# Optimize a model with 1040 rows, 678 columns and 11758 nonzeros
# Model fingerprint: 0x0a50d00a
# Variable types: 358 continuous, 320 integer (320 binary)
# Coefficient statistics:
#   Matrix range     [6e-08, 1e+02]
#   Objective range  [5e-01, 2e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [7e-03, 2e+03]
# Found heuristic solution: objective 58.7342044
# Presolve removed 692 rows and 418 columns
# Presolve time: 0.01s
# Presolved: 348 rows, 260 columns, 4325 nonzeros
# Variable types: 171 continuous, 89 integer (89 binary)
#
# Root relaxation: objective 4.823505e+01, 240 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   48.23505    0   35   58.73420   48.23505  17.9%     -    0s
# H    0     0                      48.2375438   48.23505  0.01%     -    0s
#
# Explored 1 nodes (240 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 48.2375 58.7342
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.823754379894e+01, best bound 4.823505465329e+01, gap 0.0052%
# Msys and Dsys are normlized by devise Sbase, transform to andes Sbase when do TDS
# --------------------- Results -------------------
# Total Cost: 48.2375
# RoCof prediction: 0.00475084 ; RoCof limit: 0.033
# Nadir prediction: -0.000684065 ; Nadir limit 0.01
# Simulation to t=600.00 sec completed in 0.0978 seconds.
# Simulation to t=601.00 sec completed in 0.0847 seconds.
# Simulation to t=602.00 sec completed in 0.0715 seconds.
# Simulation to t=603.00 sec completed in 0.0693 seconds.
# Simulation to t=604.00 sec completed in 0.0969 seconds.
# Simulation to t=605.00 sec completed in 0.0810 seconds.
# Simulation to t=606.00 sec completed in 0.0721 seconds.
# Simulation to t=607.00 sec completed in 0.0696 seconds.
# Simulation to t=608.00 sec completed in 0.0968 seconds.
# Simulation to t=609.00 sec completed in 0.0810 seconds.
# Simulation to t=610.00 sec completed in 0.0703 seconds.
# Simulation to t=611.00 sec completed in 0.0692 seconds.
# Simulation to t=612.00 sec completed in 0.0972 seconds.
# Simulation to t=613.00 sec completed in 0.0836 seconds.
# Simulation to t=614.00 sec completed in 0.0701 seconds.
# Simulation to t=615.00 sec completed in 0.0699 seconds.
# Simulation to t=616.00 sec completed in 0.0975 seconds.
# Simulation to t=617.00 sec completed in 0.0843 seconds.
# Simulation to t=3567.00 sec completed in 0.0678 seconds.
# Simulation to t=3568.00 sec completed in 0.0680 seconds.
# Simulation to t=3569.00 sec completed in 0.0678 seconds.
# Simulation to t=3570.00 sec completed in 0.0682 seconds.
# Simulation to t=3571.00 sec completed in 0.0689 seconds.
# Simulation to t=3572.00 sec completed in 0.0683 seconds.
# Simulation to t=3573.00 sec completed in 0.0679 seconds.
# Simulation to t=3574.00 sec completed in 0.0690 seconds.
# Simulation to t=3575.00 sec completed in 0.0682 seconds.
# Simulation to t=3576.00 sec completed in 0.0680 seconds.
# Simulation to t=3577.00 sec completed in 0.0680 seconds.
# Simulation to t=3578.00 sec completed in 0.0678 seconds.
# Simulation to t=3579.00 sec completed in 0.0680 seconds.
# Simulation to t=3580.00 sec completed in 0.0718 seconds.
# Simulation to t=3581.00 sec completed in 0.0679 seconds.
# Simulation to t=3582.00 sec completed in 0.0679 seconds.
# Simulation to t=3583.00 sec completed in 0.0682 seconds.
# Simulation to t=3584.00 sec completed in 0.0683 seconds.
# Simulation to t=3585.00 sec completed in 0.0679 seconds.
# Simulation to t=3586.00 sec completed in 0.0680 seconds.
# Simulation to t=3587.00 sec completed in 0.0676 seconds.
# Simulation to t=3588.00 sec completed in 0.0679 seconds.
# Simulation to t=3589.00 sec completed in 0.0682 seconds.
# Simulation to t=3590.00 sec completed in 0.0683 seconds.
# Simulation to t=3591.00 sec completed in 0.0684 seconds.
# Simulation to t=3592.00 sec completed in 0.0681 seconds.
# Simulation to t=3593.00 sec completed in 0.0676 seconds.
# Simulation to t=3594.00 sec completed in 0.0697 seconds.
# Simulation to t=3595.00 sec completed in 0.0683 seconds.
# Simulation to t=3596.00 sec completed in 0.0681 seconds.
# Simulation to t=3597.00 sec completed in 0.0684 seconds.
# Simulation to t=3598.00 sec completed in 0.0681 seconds.
# Simulation to t=3599.00 sec completed in 0.0683 seconds.

# %% [markdown]
# # Plot results

# %%
# plot frequency results 
ssa.TDS.plt.plot(
                ssa.GENROU.omega,
                ytimes = 60,
            )
# Out:
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:xlabel='Time [s]'>)

# %%
# plot ROCOF results
ssa.TDS.plt.plot(ssa.BusROCOF.Wf_y, ytimes=60)

# nadir
ssa.TDS.plt.plot(ssa.BusROCOF.WO_y, ytimes=60)
# Out:
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:xlabel='Time [s]'>)

# %%
# plot Pe results

ssa.TDS.plt.plot(ssa.GENROU.Pe)

ssa.TDS.plt.plot(ssa.REGCV1.Pe)
# Out:
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:xlabel='Time [s]'>)

# %%
ssa.TDS.plt.plot(ssa.GENROU.v)

ssa.TDS.plt.plot(ssa.REGCV1.v)
# Out:
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:xlabel='Time [s]'>)

# %%
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots(1, 1)
# ssa.TDS.plt.plot(ssa.REGCV1.omega, ytimes=60, fig=fig, ax=ax, show=False)
# ax.set_ylim([59.8, 60.2])
