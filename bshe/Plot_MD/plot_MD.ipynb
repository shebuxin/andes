# %%
import numpy as np
import pandas as pd
import pandapower as pp
import matplotlib.pyplot as plt

# %%
plt.style.use('ieee')
plt.rcParams['text.usetex'] = True

# %%
M_I   = np.array([6, 6, 6, 6, 6, 6, 6, 6])
M_II  = np.array([0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01])
M_III = np.array([0.11814667, 0.06732237, 0.58718068, 0.54605445, 0.37454199, 0.41813483, 0.51832465, 0.55060247])

D_I   = np.array([4, 4, 4, 4, 4, 4, 4, 4])
D_II  = np.array([0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01, 0.01])
D_III = np.array([0.02208462, 0.00709857, 0.06479399, 0.05698404, 0.07926447, 0.06375611, 0.0636579 , 0.16812373])

M_IV = np.array([1.31814667, 1.31732237, 1.93718068, 1.89605445, 1.47454199, 1.76813483, 1.86832465, 1.90060247])
D_IV = np.array([0.57208462, 0.15709857, 1.56479399, 1.55698404, 0.67926447, 1.56375611, 1.5636579 , 1.66812373])

# %%
x_labels = ['VSG1', 'VSG2', 'VSG3', 'VSG4', 'VSG5', 'VSG6', 'VSG7', 'VSG8']

# %%
plt.figure(figsize=(6/1.5, 3/1.5))

plt.stem(x_labels, M_I, linefmt='b:', markerfmt='bo', basefmt=' ', label='Scheme I')
# plt.stem(x_labels, M_IV, linefmt='c--', markerfmt='c^', basefmt=' ', label='Scheme IV')
plt.stem(x_labels, M_II, linefmt='g--', markerfmt='gs', basefmt=' ', label='Scheme II')
plt.stem(x_labels, M_III, linefmt='r', markerfmt='rx', basefmt=' ', label='Scheme III')
plt.stem(x_labels, M_IV, linefmt='c--', markerfmt='c^', basefmt=' ', label='Scheme IV')

plt.legend(loc='center', bbox_to_anchor=(0.17, 0.62))
# plt.legend(loc='upper right')
plt.xlabel('VSG index')
plt.ylabel('Virutal inertia $M$ (p.u.)')

plt.savefig('M.png', dpi=600, bbox_inches='tight')

# %%
plt.figure(figsize=(6/1.5, 3/1.5))

plt.stem(x_labels, D_I, linefmt='b:', markerfmt='bo', basefmt=' ', label='Scheme I')
# plt.stem(x_labels, M_IV, linefmt='c--', markerfmt='c^', basefmt=' ', label='Scheme IV')
plt.stem(x_labels, D_II, linefmt='g--', markerfmt='gs', basefmt=' ', label='Scheme II')
plt.stem(x_labels, D_III, linefmt='r', markerfmt='rx', basefmt=' ', label='Scheme III')
plt.stem(x_labels, D_IV, linefmt='c--', markerfmt='c^', basefmt=' ', label='Scheme IV')

plt.legend(loc='center', bbox_to_anchor=(0.17, 0.65))
plt.xlabel('VSG index')
plt.ylabel('Virutal damping $D$ (p.u.)')

plt.savefig('D.png', dpi=600, bbox_inches='tight')
