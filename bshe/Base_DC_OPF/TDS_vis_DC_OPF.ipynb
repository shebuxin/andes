# %%
import andes
import os
import matplotlib.pyplot as plt
# import matplotlib 
# %matplotlib inline
import numpy as np

# %% [markdown]
# # Load case

# %%
andes.config_logger(stream_level=20)

# case path
dir_path = os.path.abspath('..')
loc_path_case = '/Base_DC_OPF/case123_REGCV1_v6.xlsx'

case = dir_path + loc_path_case

# load a case
ssa = andes.load(case,
                 setup=True,
                 no_output=True)
# Out:
# Working directory: "/Users/buxinshe/Documents/git-repo/andes/bshe/Base_DC_OPF"
# > Loaded config from file "/Users/buxinshe/.andes/andes.rc"
# > Reloaded generated Python code of module "pycode".
# Parsing input file "/Users/buxinshe/Documents/git-repo/andes/bshe/Base_DC_OPF/case123_REGCV1_v6.xlsx"...
# Input file parsed in 0.0707 seconds.
# System internal structure set up in 0.0296 seconds.

# %% [markdown]
# # Modify case

# %%
# upper MD
M1 = np.array([1, 1, 1, 1, 1, 1, 1, 1])*2
D1 = np.array([1, 1, 1, 1, 1, 1, 1, 1])*1

# small MD with small signal issue after gen trip
M2 = np.array([1, 1, 1, 1, 1, 1, 1, 1])
D2 = np.array([1, 1, 1, 1, 1, 1, 1, 1])

# smll MD with transient stability issue after gen trip
M3 = np.array([0.0550819 , 0.05      , 0.05      , 0.18360076, 0.07189779,       0.05      , 0.23838847, 0.2688555 ])
D3 = np.array([0.08507053, 0.16234449, 0.12785225, 0.14253555, 0.29025298,       0.05      , 0.05      , 0.075514  ])

# %%
# reset REGCV1 control parameters
ssa.REGCV1.set(
                src='M', 
                idx= ssa.REGCV1.idx.v,
                attr='v',
                value= M1
            )

ssa.REGCV1.set(
                src='D', 
                idx= ssa.REGCV1.idx.v, 
                attr='v',
                value= D1
            )
# Out:
# True

# %%
# reset power setting point
ssa.PV.set(
                src='p0', 
                idx= ssa.PV.idx.v, 
                attr='v',
                value= np.array([0.05 , 0.09 , 0.07 , 0.024, 0.014, 0.012, 0.018, 0.015, 0.016, 0.017])
            )
# Out:
# True

# %%
# reset load
ssa.PQ.set(
                src='p0', 
                idx= ssa.PQ.idx.v, 
                attr='v',
                value= ssa.PQ.p0.v
            )
# Out:
# True

# %%
ssa.PFlow.run()

ssa.TDS.init()
# Out:
# -> System connectivity check results:
#   No islanded bus detected.
#   System is interconnected.
#   Each island has a slack bus correctly defined and enabled.
#
# -> Power flow calculation
#            Numba: Off
#    Sparse solver: KLU
#  Solution method: NR method
# Power flow initialized in 0.0065 seconds.
# 0: |F(x)| = 0.65
# 1: |F(x)| = 0.0002830894939
# 2: |F(x)| = 1.680238644e-07
# Converged in 3 iterations in 0.0367 seconds.
# Initialization for dynamics completed in 0.0462 seconds.
# Initialization was successful.
# array([ 1.06377037e-01,  2.09892926e-01,  7.00956018e-02,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.03730437e+00,  1.00018427e+00,
#         1.01286785e+00,  7.74223527e-02,  1.77487186e-01,  5.86934592e-02,
#         9.97254650e-01,  9.78939319e-01,  9.98210031e-01,  9.91460797e-02,
#         2.13249529e-01,  7.05197532e-02,  5.01718270e-02,  9.01737537e-02,
#         2.94106832e-02,  5.01718270e-02,  9.01737537e-02,  2.94106832e-02,
#         1.20204498e+00,  1.09098928e+00,  1.07551823e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  2.55226160e-02, -4.66009688e-03,
#        -2.12973907e-03,  2.57778422e-01, -4.70669785e-02, -2.15103646e-02,
#         1.20204498e+00,  1.09098928e+00,  1.07551823e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  5.01718270e-02,  9.01737537e-02,
#         2.94106832e-02,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         5.01718270e-02,  9.01737537e-02,  2.94106832e-02,  5.01718270e-02,
#         9.01737537e-02,  2.94106832e-02,  5.01718270e-02,  9.01737537e-02,
#         2.94106832e-02, -1.00343654e-01, -1.80347507e-01, -5.88213665e-02,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  7.74332603e-03,
#        -7.35506859e-03, -1.32086280e-02, -4.24229861e-03, -5.02148814e-03,
#        -1.29921561e-02, -9.37672410e-03, -9.83198317e-03,  7.00000000e-02,
#         2.40000000e-02,  1.40000000e-02,  1.20000000e-02,  1.80000000e-02,
#         1.50000000e-02,  1.60000000e-02,  1.70000000e-02,  3.74629594e-02,
#        -4.21613738e-02, -4.87579872e-02, -4.20122279e-02, -9.00626601e-03,
#        -3.51237650e-02, -1.73311471e-02, -1.73385862e-02,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  9.96253704e-01,
#         1.00421614e+00,  1.00487580e+00,  1.00420122e+00,  1.00090063e+00,
#         1.00351238e+00,  1.00173311e+00,  1.00173386e+00,  7.00000000e-03,
#         2.40000000e-03,  1.40000000e-03,  1.20000000e-03,  1.80000000e-03,
#         1.50000000e-03,  1.60000000e-03,  1.70000000e-03,  5.39184183e-15,
#        -4.37622020e-04, -4.63842320e-04, -6.24998489e-04, -6.85002508e-04,
#        -7.71295320e-04, -8.46368082e-04, -5.16600328e-04, -5.48471189e-04,
#         1.53607655e-03,  5.59639134e-03,  5.52150894e-03, -5.82242337e-04,
#        -1.57824847e-03,  7.29744845e-04,  2.26716380e-03,  2.15469245e-03,
#         7.74332603e-03, -6.48612728e-03, -6.63653562e-03, -6.73437226e-03,
#        -6.85340456e-03, -7.01116626e-03, -7.10703927e-03, -7.27214589e-03,
#        -7.32846248e-03, -7.35506859e-03, -7.41933054e-03, -7.45327995e-03,
#        -7.57813814e-03, -7.65099091e-03, -7.42234532e-03, -7.46721123e-03,
#        -7.56889386e-03,  8.09283052e-03, -8.10364763e-03, -8.40971289e-03,
#        -8.50014425e-03, -8.48506903e-03, -8.53406838e-03, -9.02629375e-03,
#        -9.07526352e-03, -9.92329510e-03, -1.00740938e-02, -1.05783771e-02,
#        -1.16512316e-02, -1.32086280e-02, -1.11745430e-02, -1.13168927e-02,
#        -1.14156434e-02, -1.14943626e-02, -1.15206059e-02, -2.87533041e-03,
#        -3.48193304e-03, -3.83490690e-03, -4.05306560e-03, -4.24229861e-03,
#        -4.54566042e-03, -4.62076511e-03, -4.65832987e-03, -5.91492413e-03,
#        -5.91360790e-03, -5.06207312e-03, -4.46900907e-03, -4.71181051e-03,
#        -5.00331528e-03, -5.02148814e-03, -8.15872646e-03, -8.33995391e-03,
#        -8.54784770e-03, -8.69541716e-03, -8.77871788e-03, -9.42385311e-03,
#        -1.04781938e-02, -1.17103170e-02, -1.29921561e-02, -1.01888625e-02,
#        -1.07364449e-02, -1.08418441e-02, -1.08892739e-02, -1.12426463e-02,
#        -1.15435488e-02, -1.16227469e-02, -1.16491500e-02, -1.18518716e-02,
#        -1.19967093e-02, -1.11475779e-02, -1.17176301e-02, -1.17709050e-02,
#        -1.19501224e-02, -1.20186635e-02, -1.20928579e-02, -1.21842862e-02,
#        -1.21880423e-02, -1.22718707e-02, -1.22515083e-02, -1.22819916e-02,
#        -8.45733351e-03, -8.63019885e-03, -8.86080756e-03, -8.92372500e-03,
#        -8.59874246e-03, -8.80495720e-03, -9.05343615e-03, -9.37672410e-03,
#        -8.75332684e-03, -8.88908670e-03, -9.06271514e-03, -8.79988577e-03,
#        -9.28107950e-03, -9.51113261e-03, -9.59750926e-03, -9.58810200e-03,
#        -9.83198317e-03, -9.88056925e-03, -1.15206059e-02, -8.79988577e-03,
#         1.00000000e+00,  9.98849912e-01,  9.98773096e-01,  9.98300695e-01,
#         9.98125000e-01,  9.97872254e-01,  9.97652531e-01,  9.98313525e-01,
#         9.97983105e-01,  9.98249935e-01,  9.99139579e-01,  9.98920135e-01,
#         9.97884253e-01,  9.97731549e-01,  9.98213698e-01,  9.98538082e-01,
#         9.98208679e-01,  1.00000000e+00,  9.97110309e-01,  9.96670353e-01,
#         9.96384348e-01,  9.97648740e-01,  9.97187100e-01,  9.98165529e-01,
#         9.97682145e-01,  9.98808827e-01,  1.00000000e+00,  9.99921773e-01,
#         9.98645823e-01,  9.98482817e-01,  9.98387731e-01,  9.99802660e-01,
#         9.99671093e-01,  9.99483126e-01,  1.00000000e+00,  9.96365900e-01,
#         9.95994680e-01,  9.95730503e-01,  9.95774525e-01,  9.95631416e-01,
#         9.96075217e-01,  9.95932151e-01,  9.95819402e-01,  9.95378946e-01,
#         9.95697025e-01,  9.97364638e-01,  1.00000000e+00,  9.94659220e-01,
#         9.94397830e-01,  9.94275045e-01,  9.94172732e-01,  9.94138628e-01,
#         9.97979969e-01,  9.98159138e-01,  9.98305263e-01,  9.99133947e-01,
#         1.00000000e+00,  9.97660178e-01,  9.97440394e-01,  9.97330498e-01,
#         9.96483299e-01,  9.96414331e-01,  9.98495015e-01,  1.00000000e+00,
#         9.99590769e-01,  9.99526577e-01,  1.00000000e+00,  9.95124755e-01,
#         9.94595313e-01,  9.93988591e-01,  9.93558281e-01,  9.93315530e-01,
#         9.94150450e-01,  9.95446968e-01,  9.97406831e-01,  1.00000000e+00,
#         9.93023708e-01,  9.92311920e-01,  9.92175015e-01,  9.92113502e-01,
#         9.91654689e-01,  9.91264406e-01,  9.91161782e-01,  9.91127574e-01,
#         9.90367662e-01,  9.89946934e-01,  9.91776698e-01,  9.91037036e-01,
#         9.90882179e-01,  9.90735686e-01,  9.90536515e-01,  9.90550773e-01,
#         9.90285143e-01,  9.90427504e-01,  9.90183985e-01,  9.90345335e-01,
#         9.90256790e-01,  9.95247424e-01,  9.95022442e-01,  9.94722459e-01,
#         9.94640650e-01,  9.95574688e-01,  9.96179202e-01,  9.97195479e-01,
#         1.00000000e+00,  9.95647047e-01,  9.95250474e-01,  9.94743624e-01,
#         9.95909793e-01,  9.96789791e-01,  9.97640452e-01,  9.97387702e-01,
#         9.98049854e-01,  1.00000000e+00,  9.99857496e-01,  9.94138628e-01,
#         9.95909793e-01,  7.80471002e-02,  2.42422421e-02, -3.74629594e-02,
#         4.21613738e-02,  4.87579872e-02,  4.20122279e-02,  9.00626601e-03,
#         3.51237650e-02,  1.73311471e-02,  1.73385862e-02,  2.75621493e-02,
#         2.93782282e-02,  8.25767468e-02,  4.28325545e-02,  2.95520638e-02,
#         4.21002462e-02,  8.27832023e-02,  2.73756806e-02,  9.81260485e-02,
#         2.12724011e-01,  7.00382147e-02,  9.95173994e-01,  9.77112325e-01,
#         9.97544309e-01,  5.01718270e-02,  9.01737537e-02,  2.94106832e-02,
#         5.01718270e-02,  9.01737537e-02,  2.94106832e-02,  1.20204498e+00,
#         1.09098928e+00,  1.07551823e+00,  1.20204498e+00,  1.09098928e+00,
#         1.07551823e+00,  5.00000000e-02,  9.00000000e-02,  2.93782282e-02,
#         7.80471002e-02,  2.42422421e-02,  2.75621493e-02,  9.96015999e-01,
#         9.78767989e-01,  9.98091823e-01, -9.97775834e-02, -2.13580662e-01,
#        -7.06292560e-02,  9.86972911e-02,  2.12915913e-01,  7.04094293e-02,
#         9.98134918e-01,  9.79111934e-01,  9.98329126e-01,  1.00300273e+00,
#         1.00199469e+00,  1.00080894e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  5.01718270e-02,
#         9.01737537e-02,  2.94106832e-02,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  5.01718270e-02,  9.01737537e-02,  2.94106832e-02,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  5.01718270e-02,
#         9.01737537e-02,  2.94106832e-02,  5.01718270e-02,  9.01737537e-02,
#         2.94106832e-02,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.20204498e+00,  1.09098928e+00,  1.07551823e+00,  1.02552262e+00,
#         9.95339903e-01,  9.97870261e-01,  2.64449896e-01,  6.85844094e-03,
#         0.00000000e+00,  2.55226160e-02, -4.66009688e-03, -2.12973907e-03,
#         2.55226160e-02, -4.66009688e-03, -2.12973907e-03,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  5.01718270e-02,  9.01737537e-02,  2.94106832e-02,
#         5.01718270e-02,  9.01737537e-02,  2.94106832e-02,  5.01718270e-02,
#         9.01737537e-02,  2.94106832e-02,  5.01718270e-02,  9.01737537e-02,
#         2.94106832e-02, -1.00343654e-01, -1.80347507e-01, -5.88213665e-02,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  7.00000000e-02,  2.40000000e-02,  1.40000000e-02,
#         1.20000000e-02,  1.80000000e-02,  1.50000000e-02,  1.60000000e-02,
#         1.70000000e-02,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  7.00000000e-02,  2.40000000e-02,  1.40000000e-02,
#         1.20000000e-02,  1.80000000e-02,  1.50000000e-02,  1.60000000e-02,
#         1.70000000e-02, -3.74629594e-02,  4.21613738e-02,  4.87579872e-02,
#         4.20122279e-02,  9.00626601e-03,  3.51237650e-02,  1.73311471e-02,
#         1.73385862e-02,  7.00000000e-02,  2.40000000e-02,  1.40000000e-02,
#         1.20000000e-02,  1.80000000e-02,  1.50000000e-02,  1.60000000e-02,
#         1.70000000e-02,  3.74629594e-02, -4.21613738e-02, -4.87579872e-02,
#        -4.20122279e-02, -9.00626601e-03, -3.51237650e-02, -1.73311471e-02,
#        -1.73385862e-02,  7.00000000e-02,  2.40000000e-02,  1.40000000e-02,
#         1.20000000e-02,  1.80000000e-02,  1.50000000e-02,  1.60000000e-02,
#         1.70000000e-02,  3.74629594e-02, -4.21613738e-02, -4.87579872e-02,
#        -4.20122279e-02, -9.00626601e-03, -3.51237650e-02, -1.73311471e-02,
#        -1.73385862e-02,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  9.96253704e-01,  1.00421614e+00,  1.00487580e+00,
#         1.00420122e+00,  1.00090063e+00,  1.00351238e+00,  1.00173311e+00,
#         1.00173386e+00,  7.00000000e-03,  2.40000000e-03,  1.40000000e-03,
#         1.20000000e-03,  1.80000000e-03,  1.50000000e-03,  1.60000000e-03,
#         1.70000000e-03])

# %%
ssa.EIG.run()
# Out:
# -> Eigenvalue Analysis:
# 15 states are associated with zero time constants.
#   Positive       2
#   Zeros          9
#   Negative     162
# Eigenvalue analysis finished in 0.0411 seconds.
# True

# %%
# ssa.EIG.plot()

# %%
# get the maximum eigen value
eig     = ssa.EIG.calc_eig()
eig_max = np.max(eig[0].real)
eig_max

# Note:
# For stable scenario, the maximum eigen value is extracted as positive value, but quite close to zero.
# i.e.,  2.608118165881024e-10
# This is the numerical error, and can be ignored.
# This value is supposed to be zero.
# Out:
# 7.683560827397954e-06

# %%
# Turn off stability check in TDS
ssa.TDS.config.criteria = 0

# Turn off simulation progress bar
ssa.TDS.config.no_tqdm = 1

# Simulation time
ssa.TDS.config.tf = 20

ssa.TDS.run()
# Out:
# -> Time Domain Simulation Summary:
# Sparse Solver: KLU
# Simulation time: 0.0-20 s.
# Fixed step size: h=33.33 ms. Shrink if not converged.
# <Toggle Toggler_1>: GENROU.GENROU_2 status changed to 0 at t=2.0 sec.
# Simulation to t=20.00 sec completed in 1.2581 seconds.
# True

# %%
ssa.EIG.run()

eig_     = ssa.EIG.calc_eig()
eig_max_ = np.max(eig[0].real)
eig_max_
# Out:
# -> Eigenvalue Analysis:
# 15 states are associated with zero time constants.
#   Positive       2
#   Zeros         12
#   Negative     162
# Eigenvalue analysis finished in 0.0206 seconds.
# 7.683560827397954e-06

# %% [markdown]
# # Plot

# %%
ssa.TDS.plt.plot(
                ssa.Bus.v,
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
ssa.TDS.plt.plot(
                [ssa.REGCV1.omega, ssa.GENROU.omega],
                ytimes = 60,
                legend = True
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
ssa.TDS.plt.plot(
                [ssa.REGCV1.Pe, ssa.GENROU.Pe],
                # left = 0.5,
                # right = 5,
                legend = True
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
ssa.TDS.plt.plot(
                ssa.GENROU.Pe,
                # left = 0.5,
                # right = 5,
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
# Power angle
ssa.TDS.plt.plot(
                [ssa.REGCV1.delta, ssa.GENROU.a],   # GENROW angel is bus angle
                legend = True
                )
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %% [markdown]
# ## Extract data
#
# Code clariffication for extracting simulation data after TDS:
#
# ssa.dae.ts.y:  extract **algebra** variable
#
# ssa.dae.ts.x:  extract **state** variable
#
# ....a, .a means the idx of the target variable
#
# CHECK https://docs.andes.app/en/latest/groupdoc/SynGen.html#genrou for model reference

# %%
# Extract time
t = ssa.dae.ts.t
t = t[:, np.newaxis]

# Extract RoCoF
rocof     = ssa.dae.ts.y[:,  ssa.BusROCOF.Wf_y.a]
rocof_sg  = rocof[:, [0,1,2]]
rocof_ibr = rocof[:, [3,4,5,6,7,8,9,10]]
rocof_max = np.max(np.abs(rocof*60))

# Extract frequency
f         = ssa.dae.ts.x[:,  ssa.GENROU.omega.a]
fnadir    = np.min(f)*60 - 60

# Extract voltage
busV      = ssa.dae.ts.y[:,  ssa.Bus.v.a]
busV_min  = np.min(busV)

# Extract power angle
theta           = ssa.dae.ts.y[:, ssa.GENROU.a.a]
delta_theta     = np.max(theta, axis=1) - np.min(theta, axis=1)
delta_theta_max = np.max(delta_theta)

# %% [markdown]
# ## plot RoCoF

# %%
fig = plt.figure(figsize=(8, 3))
plt.subplots_adjust(left=None, bottom=None, right=None,
                    top=None, wspace=0.6, hspace=0.3)
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)

ibr_legend = ['IBR1','IBR2','IBR3','IBR4','IBR5','IBR6','IBR7','IBR8']
sg_legend = ['SG1', 'SG2', 'SG3']

ax1.plot(
            t,
            rocof_sg * 60,
        )
ax1.set_title('(a)')
ax1.set_xlabel('Time [s]')
ax1.set_ylabel('RoCoF [Hz/s]')
ax1.legend(sg_legend)
# ax1.set_ylim([0.95, 1.12])
# ax1.set_xlim([0, 3600])

ax2.plot(
            t,
            rocof_ibr * 60,
        )
ax2.set_title('(b)')
ax2.set_xlabel('Time [s]')
ax2.set_ylabel('RoCoF [Hz/s]')
ax2.legend(ibr_legend)

# %% [markdown]
# ## Extract data after a specific time

# %%
# idx_t6 = np.min(np.where(t>6)[0])                      # find the idx of time t > 6
# f_t6   = ssa.dae.ts.x[idx_t6:,  ssa.GENROU.omega.a]    # extract the frequency after t = 6

# plt.plot(t[idx_t6:], f_t6)                             # plot the frequency after t = 6

# %% [markdown]
# # Quick results review

# %%
print('Maximum RoCoF: ', rocof_max, 'Hz/s')
print('Frequency nadir: ', fnadir, 'Hz')
print('Maximum angle difference: ', delta_theta_max, 'rad')
print('Minimum voltage: ', busV_min, 'pu')
print('Maximum eigenvalue: ', np.max([eig_max, eig_max_]))
# Out:
# Maximum RoCoF:  0.09428085214995052 Hz/s
# Frequency nadir:  -0.14309745686681907 Hz
# Maximum angle difference:  0.04366950164970351 rad
# Minimum voltage:  0.9877637286802723 pu
# Maximum eigenvalue:  7.683560827397954e-06
